# %%
"""Environment setup and library imports for Conv1D training.

Sets Keras JAX backend and configures JAX precision and memory allocation behavior.
"""

import glob
import os
import pickle
import random
import warnings

os.environ["KERAS_BACKEND"] = "jax"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.7"

import jax

# Enable JAX float64 precision natively
jax.config.update("jax_enable_x64", True)

import jax.numpy as jnp
import keras
from keras import callbacks, layers, regularizers
import numpy as np
import polars as pl

warnings.filterwarnings("ignore")

# Show enough digits to round-trip float64 diagnostics
np.set_printoptions(precision=17, floatmode="unique")

# Set seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)

print(f"Keras version : {keras.__version__}")
print(f"Keras backend : {keras.backend.backend()}")
print(f"Working dir   : {os.getcwd()}")
# Out:
# 2026-08-03 15:04:15.101390: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1785758655.114058  233333 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1785758655.118838  233333 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Keras version : 3.12.0
# Keras backend : jax
# Working dir   : /home/samer/Documents/competitions/ROGII/notebooks

# %%
def find_data_dir() -> str:
    """Searches common Kaggle and local mount points for the ROGII dataset.

    Returns:
        str: Path to the dataset directory containing 'train' subdirectory.

    Raises:
        FileNotFoundError: If the dataset cannot be found in any candidate path.
    """
    candidates = [
        "/kaggle/input/competitions/rogii-wellbore-geology-prediction",
        "/kaggle/input/rogii-wellbore-geology-prediction",
        "/home/samer/Documents/competitions/ROGII/dataset",
    ]

    for scan_root in ["/kaggle/input", "/kaggle/input/competitions"]:
        if os.path.isdir(scan_root):
            for entry in os.listdir(scan_root):
                full = os.path.join(scan_root, entry)
                if os.path.isdir(full) and full not in candidates:
                    candidates.append(full)

    print("Searching for ROGII dataset...")
    for path in candidates:
        if not os.path.isdir(path):
            continue

        contents = os.listdir(path)
        has_train = "train" in contents and os.path.isdir(os.path.join(path, "train"))
        n_train = 0
        if has_train:
            n_train = len(
                glob.glob(os.path.join(path, "train", "*__horizontal_well.csv"))
            )

        if n_train > 0:
            print(f"  V Using {path} (found {n_train} train wells)")
            return path

    raise FileNotFoundError("Could not find ROGII dataset.")


DATA_DIR = find_data_dir()
# Out:
# Searching for ROGII dataset...
#   V Using /home/samer/Documents/competitions/ROGII/dataset (found 773 train wells)

# %% [markdown]
# ### Data preparation

# %%
"""Data loading, preprocessing and preparation functions using Polars and JAX.

The Conv1D model is trained with a test-like TVT_input mask. In the competition test
wells, TVT_input is known before the submission interval and missing throughout the
interval that must be predicted. If validation keeps the true TVT_input, the model can
learn an identity shortcut and report unrealistically low validation RMSE.
"""

from typing import Dict, List, Tuple, Union
import glob
import os
import pickle
import jax
import jax.numpy as jnp
import numpy as np
import polars as pl

# Add geology-aware features to the input list
FEATURE_COLS: List[str] = [
    "MD", "X", "Y", "Z", "GR", "TVT_input", # Base features
    "inclination",                   # Engineered Feature 1
    "GR_mean_50",                    # Engineered Feature 2
    "GR_std_50",                     # Engineered Feature 3
    "dist_to_buda"                   # Engineered Feature 4
]
# Base features required for preprocessing and feature engineering.
# Includes geological markers needed for distance calculations.
BASE_FEATURE_COLS: List[str] = [
    "MD", "X", "Y", "Z", "GR", "TVT_input",
    "ANCC", "ASTNU", "ASTNL", "EGFDU", "EGFDL", "BUDA"
]
TARGET: str = "TVT"
TVT_INPUT_COL: str = "TVT_input"
MASK_START_RATIO_RANGE: Tuple[float, float] = (0.20, 0.40)


def mask_tvt_input_for_prediction_zone(
    df: pl.DataFrame,
    rng: np.random.Generator,
    ratio_range: Tuple[float, float] = MASK_START_RATIO_RANGE,
) -> Tuple[pl.DataFrame, int]:
    """Masks a suffix of TVT_input to mimic the hidden test prediction interval.

    Args:
        df (pl.DataFrame): Input DataFrame containing the well data.
        rng (np.random.Generator): Random number generator for reproducibility.
        ratio_range (Tuple[float, float]): Range of mask start ratio relative
          to well depth.

    Returns:
        Tuple[pl.DataFrame, int]: A tuple containing the masked DataFrame and
          the index where the masking started.
    """
    if TVT_INPUT_COL not in df.columns or len(df) < 2:
        return df, len(df)

    low, high = ratio_range
    mask_start = int(round(len(df) * rng.uniform(low, high)))
    mask_start = min(max(mask_start, 1), len(df) - 1)
    row_nr = pl.int_range(0, pl.len())
    df = df.with_columns(
        pl.when(row_nr >= mask_start)
        .then(None)
        .otherwise(pl.col(TVT_INPUT_COL))
        .alias(TVT_INPUT_COL)
    )
    return df, mask_start


def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    """Interpolates nulls and engineers geology-aware features.

    This function now calculates:
    1. Wellbore Inclination: Captures the angle of drilling.
    2. Rolling GR Mean (50): Smooths the Gamma Ray signal.
    3. Rolling GR Std Dev (50): Captures the texture/variability of the formation.
    4. Distance to Buda Marker: Provides relative stratigraphic position.

    Args:
        df (pl.DataFrame): Input DataFrame with missing values.

    Returns:
        pl.DataFrame: Preprocessed DataFrame with all feature columns filled.
    """
    # 1. Interpolate base features and markers first
    for col in BASE_FEATURE_COLS:       
         if col in df.columns:
            df = df.with_columns(
                pl.col(col)
                .interpolate()
                .fill_null(strategy="forward")
                .fill_null(strategy="backward")
                .fill_null(0.0)
            )

    # 2. Engineer new features from the cleaned GR and MD columns
    df = df.with_columns(
        # 1. Wellbore Inclination
        ((pl.col("Z").diff().fill_null(0)) / (pl.col("MD").diff().fill_null(1e-6)))
        .clip(-1.0, 1.0)  # Ensure input to arcsin is in [-1, 1]
        .map_elements(np.arcsin, return_dtype=pl.Float64).alias("inclination"),

        # 2. Rolling GR Mean (window 50)
        pl.col("GR").rolling_mean(window_size=50).alias("GR_mean_50"),

        # 3. Rolling GR Standard Deviation (window 50)
        pl.col("GR").rolling_std(window_size=50).alias("GR_std_50"),

        # 4. Distance to Buda Marker
        (pl.col("Z") - pl.col("BUDA")).alias("dist_to_buda")
    )

    # 3. Fill nulls generated by rolling windows and diffs
    return df.with_columns(
        pl.all().forward_fill().backward_fill().fill_null(0.0)
    )


def prepare_data(
    data_dir: str,
    val_ratio: float = 0.20,
    seed: int = 42,
    max_wells: Union[int, None] = None,
) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
    """Loads wells and builds train/validation arrays with test-like masking.

    Reshapes the inputs to 3D tensors compatible with Conv1D layers and uses JAX
    on CPU memory for double-precision normalization to avoid GPU OOM.

    Args:
        data_dir (str): Path to the training dataset.
        val_ratio (float): Fraction of wells to use for validation.
        seed (int): Random seed for split and masking reproducibility.
        max_wells (Union[int, None]): Maximum number of wells to load (for debugging).

    Returns:
        Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
          A tuple containing:
            - X_train: Preprocessed standardized training features (3D: [samples, 1, features]).
            - y_train: Standardized training target values (1D: [samples]).
            - X_val: Preprocessed standardized validation features (3D: [samples, 1, features]).
            - y_val: Standardized validation target values (1D: [samples]).
            - y_val_raw: Raw validation targets in original scale (1D: [samples]).
            - scaler: Dictionary containing standardization scaling parameters.
    """
    dataset_root = os.path.dirname(data_dir)

    # 1. Get original training IDs
    pattern_train = os.path.join(data_dir, "train", "*__horizontal_well.csv")
    files_train = sorted([os.path.basename(f) for f in glob.glob(pattern_train)])

    # 2. Get augmented training files
    # pattern_aug = os.path.join(
    #     dataset_root, "dataset_augmented", "train", "*__horizontal_well_aug.csv"
    # )
    # files_aug = sorted([os.path.basename(f) for f in glob.glob(pattern_aug)])

    # Combined training file list
    files_train_all = files_train #+ files_aug

    if max_wells:
        files_train_all = files_train_all[:max_wells]

    rng = np.random.default_rng(seed)
    n_val = max(1, int(len(files_train_all) * val_ratio))
    val_set = set(rng.permutation(len(files_train_all))[:n_val])

    train_files = [fname for i, fname in enumerate(files_train_all) if i not in val_set]
    val_files = [fname for i, fname in enumerate(files_train_all) if i in val_set]

    print(
        f"Loading {len(files_train_all)} training wells total. "
        # f"(Original: {len(files_train)}, Augmented: {len(files_aug)})."
    )

    def get_arrays(files: List[str], split_name: str) -> Tuple[np.ndarray, np.ndarray]:
        """Reads CSV files for a split, masks TVT_input, and returns merged arrays.

        Args:
            files (List[str]): List of filenames to load.
            split_name (str): Label for the dataset split (e.g. "Train", "Val").

        Returns:
            Tuple[np.ndarray, np.ndarray]: Merged features and target arrays.
        """
        feats, tgts, mask_starts = [], [], []
        for filename in files:
            try:
                # if filename in files_aug:
                #     path = os.path.join(
                #         dataset_root, "dataset_augmented", "train", filename
                #     )
                # else:
                path = os.path.join(data_dir, "train", filename)

                df = pl.read_csv(path, infer_schema_length=10000)
                df = df.filter(pl.col(TARGET).is_not_null())
                if len(df) == 0:
                    continue

                df, mask_start = mask_tvt_input_for_prediction_zone(df, rng)
                df = preprocess(df)

                feats.append(df.select(FEATURE_COLS).to_numpy().astype(np.float64))
                tgts.append(df.select(TARGET).to_numpy().ravel().astype(np.float64))
                mask_starts.append(mask_start / len(df))
            except Exception as e:
                print(f"  Skip {filename}: {e}")

        if not feats:
            raise ValueError(f"No usable wells found for {split_name} split.")

        print(
            f"{split_name} TVT_input mask start ratio: "
            f"mean={np.mean(mask_starts):.3f}, "
            f"min={np.min(mask_starts):.3f}, max={np.max(mask_starts):.3f}"
        )
        return np.concatenate(feats), np.concatenate(tgts)

    X_train_raw, y_train_raw = get_arrays(train_files, "Train")
    X_val_raw, y_val_raw = get_arrays(val_files, "Val")

    cpu_dev = jax.devices("cpu")[0]
    X_tr_jax = jax.device_put(X_train_raw, cpu_dev)
    y_tr_jax = jax.device_put(y_train_raw, cpu_dev)
    X_val_jax = jax.device_put(X_val_raw, cpu_dev)
    y_val_jax = jax.device_put(y_val_raw, cpu_dev)

    feat_mean = jnp.mean(X_tr_jax, axis=0)
    feat_std = jnp.std(X_tr_jax, axis=0)
    feat_std = jnp.where(feat_std == 0, 1.0, feat_std)

    target_mean = jnp.mean(y_tr_jax)
    target_std = jnp.std(y_tr_jax)
    target_std = jnp.where(target_std == 0, 1.0, target_std)

    X_train_n = (X_tr_jax - feat_mean) / feat_std
    y_train_n = (y_tr_jax - target_mean) / target_std
    X_val_n = (X_val_jax - feat_mean) / feat_std
    y_val_n = (y_val_jax - target_mean) / target_std

    scaler = {
        "feature_cols": FEATURE_COLS,
        "feat_mean": np.array(feat_mean),
        "feat_std": np.array(feat_std),
        "target_mean": float(target_mean),
        "target_std": float(target_std),
        "normalized": True,
        "tvt_input_masked_for_training": True,
        "mask_start_ratio_range": MASK_START_RATIO_RANGE,
    }

    # Reshape features to 3D format (samples, sequence_length=1, features) for Conv1D compatibility
    X_train_3d = np.array(X_train_n, dtype=np.float32).reshape(-1, 1, len(FEATURE_COLS))
    X_val_3d = np.array(X_val_n, dtype=np.float32).reshape(-1, 1, len(FEATURE_COLS))

    return (
        X_train_3d,
        np.array(y_train_n, dtype=np.float32),
        X_val_3d,
        np.array(y_val_n, dtype=np.float32),
        y_val_raw,
        scaler,
    )


print("Preparing dataset...")
X_train, y_train, X_val, y_val, y_val_raw, scaler = prepare_data(DATA_DIR)
print(f"Train size: {X_train.shape}, Val size: {X_val.shape}")

OUT_DIR = "../outputs"
os.makedirs(OUT_DIR, exist_ok=True)
scaler_path = os.path.join(OUT_DIR, "conv_tr_scaler_params.pkl")
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)
print(f"Scaler parameters saved to {scaler_path}")
# Out:
# Preparing dataset...
# Loading 773 training wells total.
# Train TVT_input mask start ratio: mean=0.301, min=0.200, max=0.400
# Val TVT_input mask start ratio: mean=0.295, min=0.200, max=0.399
# Train size: (4074081, 1, 10), Val size: (1018174, 1, 10)
# Scaler parameters saved to ../outputs/conv_tr_scaler_params.pkl

# %% [markdown]
# ### Model building

# %%
"""Model construction and compilation for Conv1D architecture."""

def se_block(x, ratio=8):
    """Applies Squeeze-and-Excitation channel attention."""
    channels = x.shape[-1]
    se = layers.GlobalAveragePooling1D()(x)
    se = layers.Dense(max(channels // ratio, 4), activation="relu")(se)
    se = layers.Dense(channels, activation="sigmoid")(se)
    se = layers.Reshape((1, channels))(se)
    return layers.Multiply()([x, se])

def transformer_encoder_block(x, num_heads=8, key_dim=128, dropout=0.1):
    """Builds a Transformer encoder block for sequence feature learning.

    Args:
        x: Input tensor of shape (batch, steps, channels).
        num_heads: Number of attention heads.
        key_dim: Dimensionality of the key/query/value.
        dropout: Dropout rate.

    Returns:
        Output tensor of the Transformer block.
    """
    # Self-attention layer
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    # Feed-forward network (no expansion, just normalization)
    return out1


def residual_conv1d_block(x, filters, kernel_size, dropout_rate=0.2):
    """Builds a residual Conv1D block with BatchNorm and SE attention."""
    shortcut = x
    y = layers.Conv1D(
        filters,
        kernel_size,
        padding="causal",
        kernel_initializer="he_uniform",
        kernel_regularizer=regularizers.l2(1e-4),
    )(x)
    y = layers.BatchNormalization()(y)
    y = layers.LeakyReLU(negative_slope=0.5)(y)
    y = layers.Conv1D(
        filters,
        kernel_size,
        padding="causal",
        kernel_initializer="he_uniform",
        kernel_regularizer=regularizers.l2(1e-4),
    )(y)
    y = layers.BatchNormalization()(y)
    y = se_block(y)

    if shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(
            filters,
            1,
            padding="same",
            kernel_initializer="he_uniform",
            kernel_regularizer=regularizers.l2(1e-4),
        )(shortcut)

    y = layers.Add()([shortcut, y])
    y = layers.LeakyReLU(negative_slope=0.5)(y)
    y = layers.Dropout(dropout_rate)(y)
    return y


def build_improved_conv1d_model(input_dim: int) -> keras.Model:
    """Builds and compiles the improved Residual Conv1D + SE model."""
    inputs = layers.Input(shape=(1, input_dim), name="input_layer")

    # 1. Use Conv1D blocks to extract local, scale-invariant features
    x = residual_conv1d_block(inputs, filters=64, kernel_size=8, dropout_rate=0.3)
    x = residual_conv1d_block(x, filters=128, kernel_size=8, dropout_rate=0.3)

    # 2. Use a Transformer to learn long-range dependencies between the extracted features
    x = transformer_encoder_block(x, num_heads=8, key_dim=128, dropout=0.3)

    # 3. Final MLP head for regression

    x = layers.Flatten()(x)
    x = layers.Dense(
        128,
        kernel_initializer="he_uniform",
        kernel_regularizer=regularizers.l2(1e-5),
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(negative_slope=0.5)(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(
        64,
        kernel_initializer="he_uniform",
        kernel_regularizer=regularizers.l2(1e-5),
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(negative_slope=0.5)(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(1, activation="linear")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)

    optimizer = keras.optimizers.AdamW(
        learning_rate=5e-6,  # Slightly increased LR for the larger model
        weight_decay=1e-4,
        global_clipnorm=1.0,
    )
    model.compile(
        optimizer=optimizer,
        loss="mse",
        metrics=[keras.metrics.RootMeanSquaredError(name="rmse")],
    )
    return model


model = build_improved_conv1d_model(input_dim=len(FEATURE_COLS))
print("Conv1D + Transformer Hybrid model built and compiled successfully.")
model.summary()
# Out:
# Conv1D + Transformer Hybrid model built and compiled successfully.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1, 10)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 1, 64)     │      5,184 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1, 64)     │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 1, 64)     │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 1, 64)     │     32,832 │ leaky_re_lu[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 64)     │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 64)     │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 1, 64)     │        704 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 64)     │          0 │ batch_normalizat… │
# │                     │                   │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 64)     │          0 │ conv1d_2[0][0],   │
# │                     │                   │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 1, 64)     │          0 │ add[0][0]         │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1, 64)     │          0 │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 1, 128)    │     65,664 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 128)    │        512 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 1, 128)    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 1, 128)    │    131,200 │ leaky_re_lu_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 128)    │        512 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      2,176 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 128)    │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 1, 128)    │      8,320 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 128)    │          0 │ batch_normalizat… │
# │ (Multiply)          │                   │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 128)    │          0 │ conv1d_5[0][0],   │
# │                     │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 1, 128)    │          0 │ add_1[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 128)    │          0 │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 1, 128)    │    527,488 │ dropout_1[0][0],  │
# │ (MultiHeadAttentio… │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 1, 128)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 128)    │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 1, 128)    │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 128)       │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     16,512 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ leaky_re_lu_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ leaky_re_lu_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1)         │         65 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 804,121 (3.07 MB)
#  Trainable params: 802,969 (3.06 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %% [markdown]
# ### Training

# %%
"""Train the Conv1D model with ModelCheckpoint, ReduceLROnPlateau, and EarlyStopping."""

OUT_DIR = "../outputs"
os.makedirs(OUT_DIR, exist_ok=True)
best_model_path = os.path.join(OUT_DIR, "trained_conv1d_se_model.keras")

cbs = [
    callbacks.ModelCheckpoint(
        best_model_path, monitor="val_rmse", save_best_only=True, mode="min"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_rmse", factor=0.5, patience=5, min_lr=5e-8
    ),
    # callbacks.EarlyStopping(monitor="val_rmse", patience=20, restore_best_weights=True),
]

print("Starting training of the Conv1D model...")
history = model.fit(
    X_train,
    y_train,
    epochs=2000,
    validation_data=(X_val, y_val),
    batch_size=1024,
    callbacks=cbs,
)
# Out:
# Starting training of the Conv1D model...
# Epoch 1/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 70s 12ms/step - loss: 0.7307 - rmse: 0.7944 - val_loss: 0.1937 - val_rmse: 0.3298 - learning_rate: 5.0000e-06
# Epoch 2/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.4228 - rmse: 0.5891 - val_loss: 0.1354 - val_rmse: 0.2591 - learning_rate: 5.0000e-06
# Epoch 3/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.3238 - rmse: 0.5105 - val_loss: 0.1084 - val_rmse: 0.2221 - learning_rate: 5.0000e-06
# Epoch 4/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.2593 - rmse: 0.4505 - val_loss: 0.0941 - val_rmse: 0.1999 - learning_rate: 5.0000e-06
# Epoch 5/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 0.2130 - rmse: 0.4003 - val_loss: 0.0846 - val_rmse: 0.1822 - learning_rate: 5.0000e-06
# Epoch 6/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.1777 - rmse: 0.3568 - val_loss: 0.0771 - val_rmse: 0.1666 - learning_rate: 5.0000e-06
# Epoch 7/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.1500 - rmse: 0.3187 - val_loss: 0.0729 - val_rmse: 0.1592 - learning_rate: 5.0000e-06
# Epoch 8/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.1280 - rmse: 0.2854 - val_loss: 0.0713 - val_rmse: 0.1603 - learning_rate: 5.0000e-06
# Epoch 9/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.1103 - rmse: 0.2562 - val_loss: 0.0664 - val_rmse: 0.1503 - learning_rate: 5.0000e-06
# Epoch 10/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0962 - rmse: 0.2310 - val_loss: 0.0628 - val_rmse: 0.1447 - learning_rate: 5.0000e-06
# Epoch 11/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0848 - rmse: 0.2093 - val_loss: 0.0591 - val_rmse: 0.1381 - learning_rate: 5.0000e-06
# Epoch 12/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0757 - rmse: 0.1913 - val_loss: 0.0539 - val_rmse: 0.1256 - learning_rate: 5.0000e-06
# Epoch 13/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0682 - rmse: 0.1759 - val_loss: 0.0484 - val_rmse: 0.1102 - learning_rate: 5.0000e-06
# Epoch 14/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0621 - rmse: 0.1635 - val_loss: 0.0447 - val_rmse: 0.1015 - learning_rate: 5.0000e-06
# Epoch 15/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0570 - rmse: 0.1534 - val_loss: 0.0396 - val_rmse: 0.0841 - learning_rate: 5.0000e-06
# Epoch 16/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0528 - rmse: 0.1454 - val_loss: 0.0366 - val_rmse: 0.0770 - learning_rate: 5.0000e-06
# Epoch 17/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0491 - rmse: 0.1390 - val_loss: 0.0334 - val_rmse: 0.0671 - learning_rate: 5.0000e-06
# Epoch 18/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0460 - rmse: 0.1338 - val_loss: 0.0307 - val_rmse: 0.0586 - learning_rate: 5.0000e-06
# Epoch 19/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0432 - rmse: 0.1297 - val_loss: 0.0284 - val_rmse: 0.0530 - learning_rate: 5.0000e-06
# Epoch 20/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0408 - rmse: 0.1264 - val_loss: 0.0270 - val_rmse: 0.0540 - learning_rate: 5.0000e-06
# Epoch 21/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0386 - rmse: 0.1233 - val_loss: 0.0261 - val_rmse: 0.0581 - learning_rate: 5.0000e-06
# Epoch 22/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0366 - rmse: 0.1209 - val_loss: 0.0255 - val_rmse: 0.0639 - learning_rate: 5.0000e-06
# Epoch 23/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0349 - rmse: 0.1190 - val_loss: 0.0247 - val_rmse: 0.0671 - learning_rate: 5.0000e-06
# Epoch 24/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0333 - rmse: 0.1170 - val_loss: 0.0242 - val_rmse: 0.0718 - learning_rate: 5.0000e-06
# Epoch 25/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0323 - rmse: 0.1160 - val_loss: 0.0236 - val_rmse: 0.0712 - learning_rate: 2.5000e-06
# Epoch 26/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0316 - rmse: 0.1153 - val_loss: 0.0235 - val_rmse: 0.0742 - learning_rate: 2.5000e-06
# Epoch 27/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0309 - rmse: 0.1143 - val_loss: 0.0234 - val_rmse: 0.0762 - learning_rate: 2.5000e-06
# Epoch 28/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0303 - rmse: 0.1137 - val_loss: 0.0233 - val_rmse: 0.0787 - learning_rate: 2.5000e-06
# Epoch 29/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0296 - rmse: 0.1130 - val_loss: 0.0227 - val_rmse: 0.0778 - learning_rate: 2.5000e-06
# Epoch 30/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0292 - rmse: 0.1127 - val_loss: 0.0231 - val_rmse: 0.0814 - learning_rate: 1.2500e-06
# Epoch 31/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0290 - rmse: 0.1124 - val_loss: 0.0227 - val_rmse: 0.0805 - learning_rate: 1.2500e-06
# Epoch 32/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0287 - rmse: 0.1119 - val_loss: 0.0227 - val_rmse: 0.0819 - learning_rate: 1.2500e-06
# Epoch 33/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0284 - rmse: 0.1117 - val_loss: 0.0226 - val_rmse: 0.0822 - learning_rate: 1.2500e-06
# Epoch 34/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0281 - rmse: 0.1114 - val_loss: 0.0231 - val_rmse: 0.0862 - learning_rate: 1.2500e-06
# Epoch 35/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0280 - rmse: 0.1112 - val_loss: 0.0224 - val_rmse: 0.0829 - learning_rate: 6.2500e-07
# Epoch 36/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0278 - rmse: 0.1112 - val_loss: 0.0222 - val_rmse: 0.0820 - learning_rate: 6.2500e-07
# Epoch 37/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0277 - rmse: 0.1109 - val_loss: 0.0224 - val_rmse: 0.0837 - learning_rate: 6.2500e-07
# Epoch 38/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0276 - rmse: 0.1108 - val_loss: 0.0225 - val_rmse: 0.0851 - learning_rate: 6.2500e-07
# Epoch 39/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0275 - rmse: 0.1109 - val_loss: 0.0226 - val_rmse: 0.0863 - learning_rate: 6.2500e-07
# Epoch 40/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0273 - rmse: 0.1105 - val_loss: 0.0224 - val_rmse: 0.0851 - learning_rate: 3.1250e-07
# Epoch 41/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0273 - rmse: 0.1104 - val_loss: 0.0223 - val_rmse: 0.0852 - learning_rate: 3.1250e-07
# Epoch 42/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0272 - rmse: 0.1105 - val_loss: 0.0225 - val_rmse: 0.0867 - learning_rate: 3.1250e-07
# Epoch 43/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0272 - rmse: 0.1106 - val_loss: 0.0221 - val_rmse: 0.0846 - learning_rate: 3.1250e-07
# Epoch 44/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0272 - rmse: 0.1105 - val_loss: 0.0224 - val_rmse: 0.0864 - learning_rate: 3.1250e-07
# Epoch 45/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0271 - rmse: 0.1103 - val_loss: 0.0223 - val_rmse: 0.0862 - learning_rate: 1.5625e-07
# Epoch 46/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0270 - rmse: 0.1102 - val_loss: 0.0223 - val_rmse: 0.0864 - learning_rate: 1.5625e-07
# Epoch 47/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0270 - rmse: 0.1102 - val_loss: 0.0225 - val_rmse: 0.0877 - learning_rate: 1.5625e-07
# Epoch 48/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0270 - rmse: 0.1102 - val_loss: 0.0223 - val_rmse: 0.0863 - learning_rate: 1.5625e-07
# Epoch 49/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0270 - rmse: 0.1101 - val_loss: 0.0224 - val_rmse: 0.0872 - learning_rate: 1.5625e-07
# Epoch 50/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0270 - rmse: 0.1103 - val_loss: 0.0225 - val_rmse: 0.0875 - learning_rate: 7.8125e-08
# Epoch 51/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0269 - rmse: 0.1102 - val_loss: 0.0224 - val_rmse: 0.0870 - learning_rate: 7.8125e-08
# Epoch 52/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0269 - rmse: 0.1099 - val_loss: 0.0221 - val_rmse: 0.0855 - learning_rate: 7.8125e-08
# Epoch 53/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0269 - rmse: 0.1102 - val_loss: 0.0224 - val_rmse: 0.0871 - learning_rate: 7.8125e-08
# Epoch 54/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0269 - rmse: 0.1101 - val_loss: 0.0219 - val_rmse: 0.0846 - learning_rate: 7.8125e-08
# Epoch 55/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0269 - rmse: 0.1100 - val_loss: 0.0221 - val_rmse: 0.0857 - learning_rate: 5.0000e-08
# Epoch 56/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0269 - rmse: 0.1101 - val_loss: 0.0227 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 57/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1099 - val_loss: 0.0222 - val_rmse: 0.0866 - learning_rate: 5.0000e-08
# Epoch 58/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1100 - val_loss: 0.0220 - val_rmse: 0.0850 - learning_rate: 5.0000e-08
# Epoch 59/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0269 - rmse: 0.1102 - val_loss: 0.0218 - val_rmse: 0.0840 - learning_rate: 5.0000e-08
# Epoch 60/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1101 - val_loss: 0.0226 - val_rmse: 0.0888 - learning_rate: 5.0000e-08
# Epoch 61/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1100 - val_loss: 0.0228 - val_rmse: 0.0899 - learning_rate: 5.0000e-08
# Epoch 62/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1099 - val_loss: 0.0219 - val_rmse: 0.0850 - learning_rate: 5.0000e-08
# Epoch 63/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1102 - val_loss: 0.0226 - val_rmse: 0.0889 - learning_rate: 5.0000e-08
# Epoch 64/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1102 - val_loss: 0.0222 - val_rmse: 0.0869 - learning_rate: 5.0000e-08
# Epoch 65/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1102 - val_loss: 0.0217 - val_rmse: 0.0839 - learning_rate: 5.0000e-08
# Epoch 66/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0268 - rmse: 0.1100 - val_loss: 0.0219 - val_rmse: 0.0853 - learning_rate: 5.0000e-08
# Epoch 67/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0268 - rmse: 0.1101 - val_loss: 0.0219 - val_rmse: 0.0852 - learning_rate: 5.0000e-08
# Epoch 68/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0267 - rmse: 0.1099 - val_loss: 0.0222 - val_rmse: 0.0871 - learning_rate: 5.0000e-08
# Epoch 69/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0268 - rmse: 0.1101 - val_loss: 0.0222 - val_rmse: 0.0869 - learning_rate: 5.0000e-08
# Epoch 70/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0267 - rmse: 0.1098 - val_loss: 0.0222 - val_rmse: 0.0869 - learning_rate: 5.0000e-08
# Epoch 71/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0267 - rmse: 0.1100 - val_loss: 0.0225 - val_rmse: 0.0888 - learning_rate: 5.0000e-08
# Epoch 72/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0267 - rmse: 0.1100 - val_loss: 0.0221 - val_rmse: 0.0866 - learning_rate: 5.0000e-08
# Epoch 73/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0267 - rmse: 0.1100 - val_loss: 0.0220 - val_rmse: 0.0857 - learning_rate: 5.0000e-08
# Epoch 74/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0267 - rmse: 0.1099 - val_loss: 0.0222 - val_rmse: 0.0870 - learning_rate: 5.0000e-08
# Epoch 75/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0267 - rmse: 0.1099 - val_loss: 0.0217 - val_rmse: 0.0845 - learning_rate: 5.0000e-08
# Epoch 76/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0267 - rmse: 0.1099 - val_loss: 0.0216 - val_rmse: 0.0839 - learning_rate: 5.0000e-08
# Epoch 77/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0267 - rmse: 0.1099 - val_loss: 0.0221 - val_rmse: 0.0867 - learning_rate: 5.0000e-08
# Epoch 78/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0267 - rmse: 0.1098 - val_loss: 0.0220 - val_rmse: 0.0861 - learning_rate: 5.0000e-08
# Epoch 79/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0267 - rmse: 0.1101 - val_loss: 0.0224 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 80/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0266 - rmse: 0.1097 - val_loss: 0.0225 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 81/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0266 - rmse: 0.1098 - val_loss: 0.0222 - val_rmse: 0.0875 - learning_rate: 5.0000e-08
# Epoch 82/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0266 - rmse: 0.1099 - val_loss: 0.0222 - val_rmse: 0.0876 - learning_rate: 5.0000e-08
# Epoch 83/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1098 - val_loss: 0.0219 - val_rmse: 0.0859 - learning_rate: 5.0000e-08
# Epoch 84/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1099 - val_loss: 0.0223 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 85/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1100 - val_loss: 0.0218 - val_rmse: 0.0854 - learning_rate: 5.0000e-08
# Epoch 86/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1100 - val_loss: 0.0224 - val_rmse: 0.0886 - learning_rate: 5.0000e-08
# Epoch 87/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1097 - val_loss: 0.0230 - val_rmse: 0.0920 - learning_rate: 5.0000e-08
# Epoch 88/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1097 - val_loss: 0.0222 - val_rmse: 0.0876 - learning_rate: 5.0000e-08
# Epoch 89/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0266 - rmse: 0.1098 - val_loss: 0.0222 - val_rmse: 0.0878 - learning_rate: 5.0000e-08
# Epoch 90/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1098 - val_loss: 0.0221 - val_rmse: 0.0873 - learning_rate: 5.0000e-08
# Epoch 91/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0266 - rmse: 0.1100 - val_loss: 0.0222 - val_rmse: 0.0877 - learning_rate: 5.0000e-08
# Epoch 92/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0265 - rmse: 0.1097 - val_loss: 0.0222 - val_rmse: 0.0880 - learning_rate: 5.0000e-08
# Epoch 93/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1096 - val_loss: 0.0220 - val_rmse: 0.0866 - learning_rate: 5.0000e-08
# Epoch 94/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1097 - val_loss: 0.0218 - val_rmse: 0.0857 - learning_rate: 5.0000e-08
# Epoch 95/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1098 - val_loss: 0.0222 - val_rmse: 0.0880 - learning_rate: 5.0000e-08
# Epoch 96/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0265 - rmse: 0.1098 - val_loss: 0.0217 - val_rmse: 0.0851 - learning_rate: 5.0000e-08
# Epoch 97/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1097 - val_loss: 0.0222 - val_rmse: 0.0880 - learning_rate: 5.0000e-08
# Epoch 98/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0264 - rmse: 0.1095 - val_loss: 0.0219 - val_rmse: 0.0863 - learning_rate: 5.0000e-08
# Epoch 99/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1098 - val_loss: 0.0222 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 100/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1097 - val_loss: 0.0222 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 101/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0265 - rmse: 0.1098 - val_loss: 0.0220 - val_rmse: 0.0869 - learning_rate: 5.0000e-08
# Epoch 102/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1096 - val_loss: 0.0219 - val_rmse: 0.0864 - learning_rate: 5.0000e-08
# Epoch 103/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0265 - rmse: 0.1097 - val_loss: 0.0222 - val_rmse: 0.0884 - learning_rate: 5.0000e-08
# Epoch 104/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1096 - val_loss: 0.0222 - val_rmse: 0.0880 - learning_rate: 5.0000e-08
# Epoch 105/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0265 - rmse: 0.1098 - val_loss: 0.0217 - val_rmse: 0.0853 - learning_rate: 5.0000e-08
# Epoch 106/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0264 - rmse: 0.1097 - val_loss: 0.0222 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 107/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1095 - val_loss: 0.0218 - val_rmse: 0.0860 - learning_rate: 5.0000e-08
# Epoch 108/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1098 - val_loss: 0.0219 - val_rmse: 0.0866 - learning_rate: 5.0000e-08
# Epoch 109/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1098 - val_loss: 0.0219 - val_rmse: 0.0867 - learning_rate: 5.0000e-08
# Epoch 110/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1097 - val_loss: 0.0220 - val_rmse: 0.0872 - learning_rate: 5.0000e-08
# Epoch 111/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1096 - val_loss: 0.0224 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 112/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0264 - rmse: 0.1096 - val_loss: 0.0220 - val_rmse: 0.0872 - learning_rate: 5.0000e-08
# Epoch 113/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0263 - rmse: 0.1095 - val_loss: 0.0215 - val_rmse: 0.0846 - learning_rate: 5.0000e-08
# Epoch 114/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1094 - val_loss: 0.0223 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 115/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1095 - val_loss: 0.0219 - val_rmse: 0.0871 - learning_rate: 5.0000e-08
# Epoch 116/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1095 - val_loss: 0.0221 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 117/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1094 - val_loss: 0.0221 - val_rmse: 0.0880 - learning_rate: 5.0000e-08
# Epoch 118/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1095 - val_loss: 0.0221 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 119/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1093 - val_loss: 0.0219 - val_rmse: 0.0869 - learning_rate: 5.0000e-08
# Epoch 120/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1097 - val_loss: 0.0218 - val_rmse: 0.0864 - learning_rate: 5.0000e-08
# Epoch 121/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1096 - val_loss: 0.0221 - val_rmse: 0.0885 - learning_rate: 5.0000e-08
# Epoch 122/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1096 - val_loss: 0.0221 - val_rmse: 0.0885 - learning_rate: 5.0000e-08
# Epoch 123/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1096 - val_loss: 0.0218 - val_rmse: 0.0870 - learning_rate: 5.0000e-08
# Epoch 124/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0263 - rmse: 0.1095 - val_loss: 0.0223 - val_rmse: 0.0893 - learning_rate: 5.0000e-08
# Epoch 125/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1093 - val_loss: 0.0226 - val_rmse: 0.0911 - learning_rate: 5.0000e-08
# Epoch 126/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1096 - val_loss: 0.0221 - val_rmse: 0.0886 - learning_rate: 5.0000e-08
# Epoch 127/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0263 - rmse: 0.1096 - val_loss: 0.0222 - val_rmse: 0.0890 - learning_rate: 5.0000e-08
# Epoch 128/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0262 - rmse: 0.1095 - val_loss: 0.0222 - val_rmse: 0.0892 - learning_rate: 5.0000e-08
# Epoch 129/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1095 - val_loss: 0.0219 - val_rmse: 0.0873 - learning_rate: 5.0000e-08
# Epoch 130/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1093 - val_loss: 0.0220 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 131/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0262 - rmse: 0.1094 - val_loss: 0.0222 - val_rmse: 0.0893 - learning_rate: 5.0000e-08
# Epoch 132/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1094 - val_loss: 0.0223 - val_rmse: 0.0902 - learning_rate: 5.0000e-08
# Epoch 133/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1093 - val_loss: 0.0219 - val_rmse: 0.0876 - learning_rate: 5.0000e-08
# Epoch 134/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1093 - val_loss: 0.0218 - val_rmse: 0.0871 - learning_rate: 5.0000e-08
# Epoch 135/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0262 - rmse: 0.1095 - val_loss: 0.0224 - val_rmse: 0.0905 - learning_rate: 5.0000e-08
# Epoch 136/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0216 - val_rmse: 0.0860 - learning_rate: 5.0000e-08
# Epoch 137/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0262 - rmse: 0.1094 - val_loss: 0.0221 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 138/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0221 - val_rmse: 0.0888 - learning_rate: 5.0000e-08
# Epoch 139/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0220 - val_rmse: 0.0884 - learning_rate: 5.0000e-08
# Epoch 140/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0261 - rmse: 0.1094 - val_loss: 0.0218 - val_rmse: 0.0871 - learning_rate: 5.0000e-08
# Epoch 141/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0218 - val_rmse: 0.0874 - learning_rate: 5.0000e-08
# Epoch 142/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0218 - val_rmse: 0.0877 - learning_rate: 5.0000e-08
# Epoch 143/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0261 - rmse: 0.1094 - val_loss: 0.0217 - val_rmse: 0.0871 - learning_rate: 5.0000e-08
# Epoch 144/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0261 - rmse: 0.1092 - val_loss: 0.0221 - val_rmse: 0.0893 - learning_rate: 5.0000e-08
# Epoch 145/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0218 - val_rmse: 0.0877 - learning_rate: 5.0000e-08
# Epoch 146/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0261 - rmse: 0.1094 - val_loss: 0.0218 - val_rmse: 0.0878 - learning_rate: 5.0000e-08
# Epoch 147/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0261 - rmse: 0.1093 - val_loss: 0.0217 - val_rmse: 0.0870 - learning_rate: 5.0000e-08
# Epoch 148/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0261 - rmse: 0.1094 - val_loss: 0.0223 - val_rmse: 0.0902 - learning_rate: 5.0000e-08
# Epoch 149/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0260 - rmse: 0.1091 - val_loss: 0.0221 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 150/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0260 - rmse: 0.1091 - val_loss: 0.0219 - val_rmse: 0.0881 - learning_rate: 5.0000e-08
# Epoch 151/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0260 - rmse: 0.1093 - val_loss: 0.0226 - val_rmse: 0.0921 - learning_rate: 5.0000e-08
# Epoch 152/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0260 - rmse: 0.1092 - val_loss: 0.0221 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 153/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0260 - rmse: 0.1091 - val_loss: 0.0221 - val_rmse: 0.0895 - learning_rate: 5.0000e-08
# Epoch 154/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0260 - rmse: 0.1090 - val_loss: 0.0221 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 155/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0261 - rmse: 0.1095 - val_loss: 0.0219 - val_rmse: 0.0887 - learning_rate: 5.0000e-08
# Epoch 156/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0260 - rmse: 0.1092 - val_loss: 0.0217 - val_rmse: 0.0871 - learning_rate: 5.0000e-08
# Epoch 157/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0259 - rmse: 0.1090 - val_loss: 0.0217 - val_rmse: 0.0872 - learning_rate: 5.0000e-08
# Epoch 158/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0259 - rmse: 0.1091 - val_loss: 0.0218 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 159/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0260 - rmse: 0.1091 - val_loss: 0.0222 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 160/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0260 - rmse: 0.1092 - val_loss: 0.0217 - val_rmse: 0.0878 - learning_rate: 5.0000e-08
# Epoch 161/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1091 - val_loss: 0.0218 - val_rmse: 0.0881 - learning_rate: 5.0000e-08
# Epoch 162/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0260 - rmse: 0.1093 - val_loss: 0.0219 - val_rmse: 0.0890 - learning_rate: 5.0000e-08
# Epoch 163/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1091 - val_loss: 0.0221 - val_rmse: 0.0900 - learning_rate: 5.0000e-08
# Epoch 164/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1091 - val_loss: 0.0217 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 165/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1092 - val_loss: 0.0217 - val_rmse: 0.0878 - learning_rate: 5.0000e-08
# Epoch 166/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1090 - val_loss: 0.0222 - val_rmse: 0.0905 - learning_rate: 5.0000e-08
# Epoch 167/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1090 - val_loss: 0.0218 - val_rmse: 0.0885 - learning_rate: 5.0000e-08
# Epoch 168/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0259 - rmse: 0.1090 - val_loss: 0.0220 - val_rmse: 0.0896 - learning_rate: 5.0000e-08
# Epoch 169/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0259 - rmse: 0.1090 - val_loss: 0.0220 - val_rmse: 0.0893 - learning_rate: 5.0000e-08
# Epoch 170/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0259 - rmse: 0.1091 - val_loss: 0.0225 - val_rmse: 0.0926 - learning_rate: 5.0000e-08
# Epoch 171/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0259 - rmse: 0.1092 - val_loss: 0.0220 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 172/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0259 - rmse: 0.1093 - val_loss: 0.0217 - val_rmse: 0.0878 - learning_rate: 5.0000e-08
# Epoch 173/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0258 - rmse: 0.1089 - val_loss: 0.0222 - val_rmse: 0.0910 - learning_rate: 5.0000e-08
# Epoch 174/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0258 - rmse: 0.1090 - val_loss: 0.0219 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 175/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0258 - rmse: 0.1091 - val_loss: 0.0221 - val_rmse: 0.0903 - learning_rate: 5.0000e-08
# Epoch 176/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0258 - rmse: 0.1089 - val_loss: 0.0219 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 177/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0258 - rmse: 0.1088 - val_loss: 0.0221 - val_rmse: 0.0903 - learning_rate: 5.0000e-08
# Epoch 178/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0258 - rmse: 0.1089 - val_loss: 0.0218 - val_rmse: 0.0887 - learning_rate: 5.0000e-08
# Epoch 179/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0258 - rmse: 0.1089 - val_loss: 0.0215 - val_rmse: 0.0873 - learning_rate: 5.0000e-08
# Epoch 180/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0258 - rmse: 0.1090 - val_loss: 0.0225 - val_rmse: 0.0927 - learning_rate: 5.0000e-08
# Epoch 181/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0258 - rmse: 0.1089 - val_loss: 0.0216 - val_rmse: 0.0878 - learning_rate: 5.0000e-08
# Epoch 182/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0258 - rmse: 0.1089 - val_loss: 0.0219 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 183/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0257 - rmse: 0.1088 - val_loss: 0.0220 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 184/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0258 - rmse: 0.1090 - val_loss: 0.0219 - val_rmse: 0.0895 - learning_rate: 5.0000e-08
# Epoch 185/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0257 - rmse: 0.1088 - val_loss: 0.0218 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 186/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1089 - val_loss: 0.0214 - val_rmse: 0.0868 - learning_rate: 5.0000e-08
# Epoch 187/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1089 - val_loss: 0.0218 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 188/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1089 - val_loss: 0.0216 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 189/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1090 - val_loss: 0.0214 - val_rmse: 0.0872 - learning_rate: 5.0000e-08
# Epoch 190/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0257 - rmse: 0.1087 - val_loss: 0.0216 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 191/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1090 - val_loss: 0.0215 - val_rmse: 0.0875 - learning_rate: 5.0000e-08
# Epoch 192/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0257 - rmse: 0.1087 - val_loss: 0.0220 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 193/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0257 - rmse: 0.1088 - val_loss: 0.0221 - val_rmse: 0.0908 - learning_rate: 5.0000e-08
# Epoch 194/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0217 - val_rmse: 0.0888 - learning_rate: 5.0000e-08
# Epoch 195/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1089 - val_loss: 0.0218 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 196/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0257 - rmse: 0.1090 - val_loss: 0.0217 - val_rmse: 0.0886 - learning_rate: 5.0000e-08
# Epoch 197/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0214 - val_rmse: 0.0869 - learning_rate: 5.0000e-08
# Epoch 198/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1087 - val_loss: 0.0218 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 199/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1089 - val_loss: 0.0217 - val_rmse: 0.0889 - learning_rate: 5.0000e-08
# Epoch 200/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0223 - val_rmse: 0.0920 - learning_rate: 5.0000e-08
# Epoch 201/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1089 - val_loss: 0.0219 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 202/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1087 - val_loss: 0.0215 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 203/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0256 - rmse: 0.1087 - val_loss: 0.0216 - val_rmse: 0.0885 - learning_rate: 5.0000e-08
# Epoch 204/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0221 - val_rmse: 0.0913 - learning_rate: 5.0000e-08
# Epoch 205/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0216 - val_rmse: 0.0886 - learning_rate: 5.0000e-08
# Epoch 206/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0217 - val_rmse: 0.0893 - learning_rate: 5.0000e-08
# Epoch 207/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0256 - rmse: 0.1090 - val_loss: 0.0218 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 208/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0217 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 209/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0221 - val_rmse: 0.0915 - learning_rate: 5.0000e-08
# Epoch 210/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0215 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 211/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 26s 7ms/step - loss: 0.0256 - rmse: 0.1088 - val_loss: 0.0216 - val_rmse: 0.0890 - learning_rate: 5.0000e-08
# Epoch 212/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0255 - rmse: 0.1088 - val_loss: 0.0217 - val_rmse: 0.0894 - learning_rate: 5.0000e-08
# Epoch 213/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0255 - rmse: 0.1088 - val_loss: 0.0219 - val_rmse: 0.0908 - learning_rate: 5.0000e-08
# Epoch 214/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0255 - rmse: 0.1088 - val_loss: 0.0217 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 215/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0255 - rmse: 0.1086 - val_loss: 0.0218 - val_rmse: 0.0899 - learning_rate: 5.0000e-08
# Epoch 216/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0254 - rmse: 0.1084 - val_loss: 0.0219 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 217/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0254 - rmse: 0.1085 - val_loss: 0.0220 - val_rmse: 0.0913 - learning_rate: 5.0000e-08
# Epoch 218/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0255 - rmse: 0.1089 - val_loss: 0.0218 - val_rmse: 0.0902 - learning_rate: 5.0000e-08
# Epoch 219/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0255 - rmse: 0.1086 - val_loss: 0.0214 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 220/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0255 - rmse: 0.1087 - val_loss: 0.0214 - val_rmse: 0.0879 - learning_rate: 5.0000e-08
# Epoch 221/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0255 - rmse: 0.1088 - val_loss: 0.0211 - val_rmse: 0.0866 - learning_rate: 5.0000e-08
# Epoch 222/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0255 - rmse: 0.1087 - val_loss: 0.0221 - val_rmse: 0.0918 - learning_rate: 5.0000e-08
# Epoch 223/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0255 - rmse: 0.1087 - val_loss: 0.0217 - val_rmse: 0.0896 - learning_rate: 5.0000e-08
# Epoch 224/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0254 - rmse: 0.1086 - val_loss: 0.0216 - val_rmse: 0.0890 - learning_rate: 5.0000e-08
# Epoch 225/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0254 - rmse: 0.1086 - val_loss: 0.0219 - val_rmse: 0.0907 - learning_rate: 5.0000e-08
# Epoch 226/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0254 - rmse: 0.1086 - val_loss: 0.0218 - val_rmse: 0.0902 - learning_rate: 5.0000e-08
# Epoch 227/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0254 - rmse: 0.1086 - val_loss: 0.0219 - val_rmse: 0.0911 - learning_rate: 5.0000e-08
# Epoch 228/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0254 - rmse: 0.1085 - val_loss: 0.0217 - val_rmse: 0.0898 - learning_rate: 5.0000e-08
# Epoch 229/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0254 - rmse: 0.1086 - val_loss: 0.0215 - val_rmse: 0.0887 - learning_rate: 5.0000e-08
# Epoch 230/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0214 - val_rmse: 0.0884 - learning_rate: 5.0000e-08
# Epoch 231/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0215 - val_rmse: 0.0891 - learning_rate: 5.0000e-08
# Epoch 232/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0253 - rmse: 0.1083 - val_loss: 0.0218 - val_rmse: 0.0908 - learning_rate: 5.0000e-08
# Epoch 233/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0253 - rmse: 0.1083 - val_loss: 0.0218 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 234/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0214 - val_rmse: 0.0885 - learning_rate: 5.0000e-08
# Epoch 235/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0253 - rmse: 0.1085 - val_loss: 0.0214 - val_rmse: 0.0883 - learning_rate: 5.0000e-08
# Epoch 236/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0254 - rmse: 0.1087 - val_loss: 0.0213 - val_rmse: 0.0882 - learning_rate: 5.0000e-08
# Epoch 237/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 26s 6ms/step - loss: 0.0253 - rmse: 0.1085 - val_loss: 0.0216 - val_rmse: 0.0895 - learning_rate: 5.0000e-08
# Epoch 238/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0217 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 239/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0220 - val_rmse: 0.0920 - learning_rate: 5.0000e-08
# Epoch 240/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0219 - val_rmse: 0.0916 - learning_rate: 5.0000e-08
# Epoch 241/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1084 - val_loss: 0.0217 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 242/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1086 - val_loss: 0.0216 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 243/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1083 - val_loss: 0.0218 - val_rmse: 0.0910 - learning_rate: 5.0000e-08
# Epoch 244/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1083 - val_loss: 0.0215 - val_rmse: 0.0892 - learning_rate: 5.0000e-08
# Epoch 245/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1086 - val_loss: 0.0216 - val_rmse: 0.0900 - learning_rate: 5.0000e-08
# Epoch 246/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0253 - rmse: 0.1085 - val_loss: 0.0221 - val_rmse: 0.0925 - learning_rate: 5.0000e-08
# Epoch 247/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0218 - val_rmse: 0.0913 - learning_rate: 5.0000e-08
# Epoch 248/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0215 - val_rmse: 0.0895 - learning_rate: 5.0000e-08
# Epoch 249/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1083 - val_loss: 0.0214 - val_rmse: 0.0889 - learning_rate: 5.0000e-08
# Epoch 250/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0220 - val_rmse: 0.0922 - learning_rate: 5.0000e-08
# Epoch 251/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0215 - val_rmse: 0.0898 - learning_rate: 5.0000e-08
# Epoch 252/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0252 - rmse: 0.1083 - val_loss: 0.0215 - val_rmse: 0.0899 - learning_rate: 5.0000e-08
# Epoch 253/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1085 - val_loss: 0.0217 - val_rmse: 0.0910 - learning_rate: 5.0000e-08
# Epoch 254/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0216 - val_rmse: 0.0902 - learning_rate: 5.0000e-08
# Epoch 255/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0219 - val_rmse: 0.0921 - learning_rate: 5.0000e-08
# Epoch 256/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0251 - rmse: 0.1082 - val_loss: 0.0217 - val_rmse: 0.0908 - learning_rate: 5.0000e-08
# Epoch 257/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0252 - rmse: 0.1084 - val_loss: 0.0219 - val_rmse: 0.0922 - learning_rate: 5.0000e-08
# Epoch 258/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0252 - rmse: 0.1083 - val_loss: 0.0215 - val_rmse: 0.0898 - learning_rate: 5.0000e-08
# Epoch 259/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0252 - rmse: 0.1085 - val_loss: 0.0211 - val_rmse: 0.0876 - learning_rate: 5.0000e-08
# Epoch 260/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1082 - val_loss: 0.0216 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 261/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1083 - val_loss: 0.0219 - val_rmse: 0.0922 - learning_rate: 5.0000e-08
# Epoch 262/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1083 - val_loss: 0.0219 - val_rmse: 0.0921 - learning_rate: 5.0000e-08
# Epoch 263/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1084 - val_loss: 0.0219 - val_rmse: 0.0922 - learning_rate: 5.0000e-08
# Epoch 264/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1084 - val_loss: 0.0218 - val_rmse: 0.0918 - learning_rate: 5.0000e-08
# Epoch 265/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1084 - val_loss: 0.0215 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 266/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1082 - val_loss: 0.0216 - val_rmse: 0.0907 - learning_rate: 5.0000e-08
# Epoch 267/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1081 - val_loss: 0.0220 - val_rmse: 0.0929 - learning_rate: 5.0000e-08
# Epoch 268/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1081 - val_loss: 0.0219 - val_rmse: 0.0922 - learning_rate: 5.0000e-08
# Epoch 269/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0251 - rmse: 0.1084 - val_loss: 0.0216 - val_rmse: 0.0909 - learning_rate: 5.0000e-08
# Epoch 270/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0250 - rmse: 0.1080 - val_loss: 0.0214 - val_rmse: 0.0900 - learning_rate: 5.0000e-08
# Epoch 271/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0250 - rmse: 0.1080 - val_loss: 0.0214 - val_rmse: 0.0900 - learning_rate: 5.0000e-08
# Epoch 272/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0250 - rmse: 0.1082 - val_loss: 0.0217 - val_rmse: 0.0914 - learning_rate: 5.0000e-08
# Epoch 273/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0250 - rmse: 0.1082 - val_loss: 0.0222 - val_rmse: 0.0942 - learning_rate: 5.0000e-08
# Epoch 274/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0250 - rmse: 0.1079 - val_loss: 0.0214 - val_rmse: 0.0899 - learning_rate: 5.0000e-08
# Epoch 275/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0250 - rmse: 0.1080 - val_loss: 0.0215 - val_rmse: 0.0903 - learning_rate: 5.0000e-08
# Epoch 276/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0250 - rmse: 0.1080 - val_loss: 0.0215 - val_rmse: 0.0903 - learning_rate: 5.0000e-08
# Epoch 277/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0250 - rmse: 0.1082 - val_loss: 0.0216 - val_rmse: 0.0912 - learning_rate: 5.0000e-08
# Epoch 278/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0250 - rmse: 0.1080 - val_loss: 0.0217 - val_rmse: 0.0918 - learning_rate: 5.0000e-08
# Epoch 279/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0250 - rmse: 0.1080 - val_loss: 0.0217 - val_rmse: 0.0917 - learning_rate: 5.0000e-08
# Epoch 280/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0250 - rmse: 0.1081 - val_loss: 0.0216 - val_rmse: 0.0913 - learning_rate: 5.0000e-08
# Epoch 281/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 27s 7ms/step - loss: 0.0250 - rmse: 0.1082 - val_loss: 0.0219 - val_rmse: 0.0930 - learning_rate: 5.0000e-08
# Epoch 282/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0249 - rmse: 0.1080 - val_loss: 0.0215 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 283/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0250 - rmse: 0.1081 - val_loss: 0.0215 - val_rmse: 0.0908 - learning_rate: 5.0000e-08
# Epoch 284/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0250 - rmse: 0.1081 - val_loss: 0.0215 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 285/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1080 - val_loss: 0.0211 - val_rmse: 0.0884 - learning_rate: 5.0000e-08
# Epoch 286/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0250 - rmse: 0.1082 - val_loss: 0.0211 - val_rmse: 0.0888 - learning_rate: 5.0000e-08
# Epoch 287/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1079 - val_loss: 0.0213 - val_rmse: 0.0897 - learning_rate: 5.0000e-08
# Epoch 288/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0250 - rmse: 0.1083 - val_loss: 0.0215 - val_rmse: 0.0907 - learning_rate: 5.0000e-08
# Epoch 289/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1081 - val_loss: 0.0213 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 290/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1079 - val_loss: 0.0216 - val_rmse: 0.0917 - learning_rate: 5.0000e-08
# Epoch 291/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1080 - val_loss: 0.0222 - val_rmse: 0.0945 - learning_rate: 5.0000e-08
# Epoch 292/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0249 - rmse: 0.1079 - val_loss: 0.0219 - val_rmse: 0.0934 - learning_rate: 5.0000e-08
# Epoch 293/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1079 - val_loss: 0.0211 - val_rmse: 0.0889 - learning_rate: 5.0000e-08
# Epoch 294/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1080 - val_loss: 0.0220 - val_rmse: 0.0936 - learning_rate: 5.0000e-08
# Epoch 295/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1081 - val_loss: 0.0210 - val_rmse: 0.0885 - learning_rate: 5.0000e-08
# Epoch 296/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0249 - rmse: 0.1081 - val_loss: 0.0216 - val_rmse: 0.0915 - learning_rate: 5.0000e-08
# Epoch 297/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0249 - rmse: 0.1080 - val_loss: 0.0214 - val_rmse: 0.0907 - learning_rate: 5.0000e-08
# Epoch 298/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0214 - val_rmse: 0.0909 - learning_rate: 5.0000e-08
# Epoch 299/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1080 - val_loss: 0.0216 - val_rmse: 0.0916 - learning_rate: 5.0000e-08
# Epoch 300/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0213 - val_rmse: 0.0901 - learning_rate: 5.0000e-08
# Epoch 301/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1080 - val_loss: 0.0212 - val_rmse: 0.0896 - learning_rate: 5.0000e-08
# Epoch 302/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0214 - val_rmse: 0.0910 - learning_rate: 5.0000e-08
# Epoch 303/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0248 - rmse: 0.1081 - val_loss: 0.0215 - val_rmse: 0.0915 - learning_rate: 5.0000e-08
# Epoch 304/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0214 - val_rmse: 0.0909 - learning_rate: 5.0000e-08
# Epoch 305/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0213 - val_rmse: 0.0902 - learning_rate: 5.0000e-08
# Epoch 306/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0248 - rmse: 0.1078 - val_loss: 0.0213 - val_rmse: 0.0906 - learning_rate: 5.0000e-08
# Epoch 307/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0215 - val_rmse: 0.0913 - learning_rate: 5.0000e-08
# Epoch 308/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0248 - rmse: 0.1080 - val_loss: 0.0210 - val_rmse: 0.0887 - learning_rate: 5.0000e-08
# Epoch 309/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0248 - rmse: 0.1079 - val_loss: 0.0215 - val_rmse: 0.0913 - learning_rate: 5.0000e-08
# Epoch 310/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 25s 6ms/step - loss: 0.0247 - rmse: 0.1078 - val_loss: 0.0215 - val_rmse: 0.0914 - learning_rate: 5.0000e-08
# Epoch 311/2000
# ...
# Epoch 820/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0216 - rmse: 0.1047 - val_loss: 0.0200 - val_rmse: 0.0966 - learning_rate: 5.0000e-08
# Epoch 821/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0216 - rmse: 0.1047 - val_loss: 0.0204 - val_rmse: 0.0989 - learning_rate: 5.0000e-08
# Epoch 822/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0211 - val_rmse: 0.1024 - learning_rate: 5.0000e-08
# Epoch 823/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0203 - val_rmse: 0.0985 - learning_rate: 5.0000e-08
# Epoch 824/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1044 - val_loss: 0.0200 - val_rmse: 0.0971 - learning_rate: 5.0000e-08
# Epoch 825/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1043 - val_loss: 0.0208 - val_rmse: 0.1009 - learning_rate: 5.0000e-08
# Epoch 826/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0206 - val_rmse: 0.1001 - learning_rate: 5.0000e-08
# Epoch 827/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1046 - val_loss: 0.0203 - val_rmse: 0.0987 - learning_rate: 5.0000e-08
# Epoch 828/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1042 - val_loss: 0.0202 - val_rmse: 0.0978 - learning_rate: 5.0000e-08
# Epoch 829/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1043 - val_loss: 0.0198 - val_rmse: 0.0957 - learning_rate: 5.0000e-08
# Epoch 830/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0205 - val_rmse: 0.0996 - learning_rate: 5.0000e-08
# Epoch 831/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1044 - val_loss: 0.0203 - val_rmse: 0.0987 - learning_rate: 5.0000e-08
# Epoch 832/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0202 - val_rmse: 0.0980 - learning_rate: 5.0000e-08
# Epoch 833/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0201 - val_rmse: 0.0975 - learning_rate: 5.0000e-08
# Epoch 834/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1043 - val_loss: 0.0204 - val_rmse: 0.0989 - learning_rate: 5.0000e-08
# Epoch 835/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0206 - val_rmse: 0.1001 - learning_rate: 5.0000e-08
# Epoch 836/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1044 - val_loss: 0.0206 - val_rmse: 0.1000 - learning_rate: 5.0000e-08
# Epoch 837/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1044 - val_loss: 0.0202 - val_rmse: 0.0982 - learning_rate: 5.0000e-08
# Epoch 838/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0206 - val_rmse: 0.1004 - learning_rate: 5.0000e-08
# Epoch 839/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0199 - val_rmse: 0.0964 - learning_rate: 5.0000e-08
# Epoch 840/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1044 - val_loss: 0.0200 - val_rmse: 0.0975 - learning_rate: 5.0000e-08
# Epoch 841/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0215 - rmse: 0.1045 - val_loss: 0.0201 - val_rmse: 0.0975 - learning_rate: 5.0000e-08
# Epoch 842/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1041 - val_loss: 0.0206 - val_rmse: 0.1004 - learning_rate: 5.0000e-08
# Epoch 843/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1042 - val_loss: 0.0203 - val_rmse: 0.0989 - learning_rate: 5.0000e-08
# Epoch 844/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0199 - val_rmse: 0.0967 - learning_rate: 5.0000e-08
# Epoch 845/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0199 - val_rmse: 0.0969 - learning_rate: 5.0000e-08
# Epoch 846/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0206 - val_rmse: 0.1005 - learning_rate: 5.0000e-08
# Epoch 847/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1045 - val_loss: 0.0207 - val_rmse: 0.1010 - learning_rate: 5.0000e-08
# Epoch 848/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0206 - val_rmse: 0.1005 - learning_rate: 5.0000e-08
# Epoch 849/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1044 - val_loss: 0.0199 - val_rmse: 0.0971 - learning_rate: 5.0000e-08
# Epoch 850/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1042 - val_loss: 0.0204 - val_rmse: 0.0993 - learning_rate: 5.0000e-08
# Epoch 851/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1045 - val_loss: 0.0207 - val_rmse: 0.1009 - learning_rate: 5.0000e-08
# Epoch 852/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0202 - val_rmse: 0.0985 - learning_rate: 5.0000e-08
# Epoch 853/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0213 - val_rmse: 0.1038 - learning_rate: 5.0000e-08
# Epoch 854/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0206 - val_rmse: 0.1008 - learning_rate: 5.0000e-08
# Epoch 855/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1044 - val_loss: 0.0206 - val_rmse: 0.1008 - learning_rate: 5.0000e-08
# Epoch 856/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0208 - val_rmse: 0.1014 - learning_rate: 5.0000e-08
# Epoch 857/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0202 - val_rmse: 0.0987 - learning_rate: 5.0000e-08
# Epoch 858/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1041 - val_loss: 0.0205 - val_rmse: 0.1000 - learning_rate: 5.0000e-08
# Epoch 859/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1040 - val_loss: 0.0202 - val_rmse: 0.0985 - learning_rate: 5.0000e-08
# Epoch 860/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0214 - rmse: 0.1043 - val_loss: 0.0203 - val_rmse: 0.0990 - learning_rate: 5.0000e-08
# Epoch 861/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1041 - val_loss: 0.0199 - val_rmse: 0.0974 - learning_rate: 5.0000e-08
# Epoch 862/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1043 - val_loss: 0.0203 - val_rmse: 0.0993 - learning_rate: 5.0000e-08
# Epoch 863/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0203 - val_rmse: 0.0993 - learning_rate: 5.0000e-08
# Epoch 864/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1041 - val_loss: 0.0201 - val_rmse: 0.0982 - learning_rate: 5.0000e-08
# Epoch 865/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0206 - val_rmse: 0.1005 - learning_rate: 5.0000e-08
# Epoch 866/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1044 - val_loss: 0.0204 - val_rmse: 0.0996 - learning_rate: 5.0000e-08
# Epoch 867/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1043 - val_loss: 0.0205 - val_rmse: 0.1001 - learning_rate: 5.0000e-08
# Epoch 868/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0200 - val_rmse: 0.0980 - learning_rate: 5.0000e-08
# Epoch 869/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1043 - val_loss: 0.0204 - val_rmse: 0.0998 - learning_rate: 5.0000e-08
# Epoch 870/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1041 - val_loss: 0.0200 - val_rmse: 0.0977 - learning_rate: 5.0000e-08
# Epoch 871/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1044 - val_loss: 0.0199 - val_rmse: 0.0975 - learning_rate: 5.0000e-08
# Epoch 872/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1040 - val_loss: 0.0205 - val_rmse: 0.1006 - learning_rate: 5.0000e-08
# Epoch 873/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1041 - val_loss: 0.0200 - val_rmse: 0.0978 - learning_rate: 5.0000e-08
# Epoch 874/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1041 - val_loss: 0.0204 - val_rmse: 0.1001 - learning_rate: 5.0000e-08
# Epoch 875/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0200 - val_rmse: 0.0977 - learning_rate: 5.0000e-08
# Epoch 876/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0203 - val_rmse: 0.0995 - learning_rate: 5.0000e-08
# Epoch 877/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1042 - val_loss: 0.0200 - val_rmse: 0.0978 - learning_rate: 5.0000e-08
# Epoch 878/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1041 - val_loss: 0.0200 - val_rmse: 0.0982 - learning_rate: 5.0000e-08
# Epoch 879/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1041 - val_loss: 0.0201 - val_rmse: 0.0988 - learning_rate: 5.0000e-08
# Epoch 880/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1043 - val_loss: 0.0201 - val_rmse: 0.0984 - learning_rate: 5.0000e-08
# Epoch 881/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1041 - val_loss: 0.0201 - val_rmse: 0.0988 - learning_rate: 5.0000e-08
# Epoch 882/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1042 - val_loss: 0.0203 - val_rmse: 0.0998 - learning_rate: 5.0000e-08
# Epoch 883/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1040 - val_loss: 0.0200 - val_rmse: 0.0981 - learning_rate: 5.0000e-08
# Epoch 884/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1043 - val_loss: 0.0206 - val_rmse: 0.1012 - learning_rate: 5.0000e-08
# Epoch 885/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1043 - val_loss: 0.0200 - val_rmse: 0.0983 - learning_rate: 5.0000e-08
# Epoch 886/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1040 - val_loss: 0.0198 - val_rmse: 0.0970 - learning_rate: 5.0000e-08
# Epoch 887/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0213 - rmse: 0.1044 - val_loss: 0.0204 - val_rmse: 0.1003 - learning_rate: 5.0000e-08
# Epoch 888/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1041 - val_loss: 0.0203 - val_rmse: 0.0997 - learning_rate: 5.0000e-08
# Epoch 889/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1041 - val_loss: 0.0204 - val_rmse: 0.1003 - learning_rate: 5.0000e-08
# Epoch 890/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1040 - val_loss: 0.0201 - val_rmse: 0.0988 - learning_rate: 5.0000e-08
# Epoch 891/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1041 - val_loss: 0.0202 - val_rmse: 0.0992 - learning_rate: 5.0000e-08
# Epoch 892/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1040 - val_loss: 0.0206 - val_rmse: 0.1011 - learning_rate: 5.0000e-08
# Epoch 893/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1042 - val_loss: 0.0203 - val_rmse: 0.1001 - learning_rate: 5.0000e-08
# Epoch 894/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1040 - val_loss: 0.0200 - val_rmse: 0.0985 - learning_rate: 5.0000e-08
# Epoch 895/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0202 - val_rmse: 0.0991 - learning_rate: 5.0000e-08
# Epoch 896/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0204 - val_rmse: 0.1003 - learning_rate: 5.0000e-08
# Epoch 897/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0205 - val_rmse: 0.1011 - learning_rate: 5.0000e-08
# Epoch 898/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1038 - val_loss: 0.0200 - val_rmse: 0.0982 - learning_rate: 5.0000e-08
# Epoch 899/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1039 - val_loss: 0.0203 - val_rmse: 0.1002 - learning_rate: 5.0000e-08
# Epoch 900/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1038 - val_loss: 0.0203 - val_rmse: 0.0999 - learning_rate: 5.0000e-08
# Epoch 901/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1042 - val_loss: 0.0197 - val_rmse: 0.0969 - learning_rate: 5.0000e-08
# Epoch 902/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0212 - rmse: 0.1042 - val_loss: 0.0201 - val_rmse: 0.0991 - learning_rate: 5.0000e-08
# Epoch 903/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1041 - val_loss: 0.0202 - val_rmse: 0.0994 - learning_rate: 5.0000e-08
# Epoch 904/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0202 - val_rmse: 0.0994 - learning_rate: 5.0000e-08
# Epoch 905/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1042 - val_loss: 0.0209 - val_rmse: 0.1031 - learning_rate: 5.0000e-08
# Epoch 906/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0207 - val_rmse: 0.1019 - learning_rate: 5.0000e-08
# Epoch 907/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0204 - val_rmse: 0.1005 - learning_rate: 5.0000e-08
# Epoch 908/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0199 - val_rmse: 0.0979 - learning_rate: 5.0000e-08
# Epoch 909/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1042 - val_loss: 0.0203 - val_rmse: 0.1000 - learning_rate: 5.0000e-08
# Epoch 910/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0201 - val_rmse: 0.0994 - learning_rate: 5.0000e-08
# Epoch 911/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0210 - rmse: 0.1038 - val_loss: 0.0205 - val_rmse: 0.1011 - learning_rate: 5.0000e-08
# Epoch 912/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0211 - rmse: 0.1042 - val_loss: 0.0204 - val_rmse: 0.1006 - learning_rate: 5.0000e-08
# Epoch 913/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1041 - val_loss: 0.0203 - val_rmse: 0.1002 - learning_rate: 5.0000e-08
# Epoch 914/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0198 - val_rmse: 0.0978 - learning_rate: 5.0000e-08
# Epoch 915/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0210 - rmse: 0.1039 - val_loss: 0.0205 - val_rmse: 0.1013 - learning_rate: 5.0000e-08
# Epoch 916/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1041 - val_loss: 0.0201 - val_rmse: 0.0993 - learning_rate: 5.0000e-08
# Epoch 917/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0210 - rmse: 0.1039 - val_loss: 0.0207 - val_rmse: 0.1022 - learning_rate: 5.0000e-08
# Epoch 918/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1041 - val_loss: 0.0195 - val_rmse: 0.0965 - learning_rate: 5.0000e-08
# Epoch 919/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 0.0210 - rmse: 0.1039 - val_loss: 0.0205 - val_rmse: 0.1015 - learning_rate: 5.0000e-08
# Epoch 920/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1040 - val_loss: 0.0205 - val_rmse: 0.1013 - learning_rate: 5.0000e-08
# Epoch 921/2000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - loss: 0.0211 - rmse: 0.1041 - val_loss: 0.0202 - val_rmse: 0.1000 - learning_rate: 5.0000e-08
# Epoch 922/2000
# 3969/3979 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0210 - rmse: 0.1039

# %% [markdown]
# ### Evaluation

# %%
"""Load the best model and evaluate its final RMSE on raw scale using JAX."""

# Denormalize using JAX on CPU device
cpu_dev = jax.devices("cpu")[0]
target_mean = jax.device_put(scaler["target_mean"], cpu_dev)
target_std = jax.device_put(scaler["target_std"], cpu_dev)
y_val_raw_jnp = jax.device_put(y_val_raw, cpu_dev)

# Predict on val set (normalized scale)
yp_n = model.predict(X_val, batch_size=128).ravel()
yp_n_jnp = jax.device_put(yp_n, cpu_dev)

# Denormalize predictions
yp_jnp = (yp_n_jnp * target_std) + target_mean

# Calculate error and RMSE using JAX
err = yp_jnp - y_val_raw_jnp
rmse = float(jnp.sqrt(jnp.mean(jnp.square(err))))
print(f"\nFinal Val RMSE (Optimized Conv1D Model, RAW SCALE): {rmse:.4f}")
# Out:
# 7955/7955 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step
#
# Final Val RMSE (Optimized Conv1D Model, RAW SCALE): 40.3881

# %%
"""Plots training and validation curves and saves them to the analytics directory."""

import matplotlib.pyplot as plt

ANALYTICS_DIR = "../analytics"
os.makedirs(ANALYTICS_DIR, exist_ok=True)


def plot_history(history):
    """Plots model loss and root mean squared error curves.

    Args:
        history: Keras History object.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Loss curve
    ax1.plot(history.history["loss"], label="Train")
    ax1.plot(history.history["val_loss"], label="Val")
    ax1.set_title("Conv1D Model Loss (MSE)")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.legend()
    ax1.grid(True)

    # RMSE curve
    ax2.plot(history.history["rmse"], label="Train")
    ax2.plot(history.history["val_rmse"], label="Val")
    ax2.set_title("Conv1D Model RMSE")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("RMSE")
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.savefig(os.path.join(ANALYTICS_DIR, "conv1d_training_history.png"))
    plt.show()


if "history" in locals():
    plot_history(history)

# %%
def plot_pred_vs_actual(y_true, y_pred, val_rmse):
    """Plots predicted vs actual values on raw scale and saves it to analytics."""
    plt.figure(figsize=(10, 6))
    plt.scatter(np.array(y_true), np.array(y_pred), alpha=0.1, s=1, color="blue")

    # Draw perfect prediction line
    min_val = min(float(y_true.min()), float(y_pred.min()))
    max_val = max(float(y_true.max()), float(y_pred.max()))
    plt.plot(
        [min_val, max_val], [min_val, max_val], "r--", lw=2, label="Perfect Prediction"
    )

    plt.title(f"Actual vs Predicted TVT (Val Set - Conv1D)\nRMSE: {val_rmse:.4f}")
    plt.xlabel("Actual TVT")
    plt.ylabel("Predicted TVT")
    plt.legend()
    plt.grid(True)

    plt.savefig(os.path.join(ANALYTICS_DIR, "conv1d_val_pred_vs_actual.png"))
    plt.show()


if "y_val_raw" in locals() and "yp_jnp" in locals():
    plot_pred_vs_actual(y_val_raw, yp_jnp, rmse)
