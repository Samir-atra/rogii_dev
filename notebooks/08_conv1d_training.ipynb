# %%
"""Environment setup and library imports for Conv1D training.

Sets Keras JAX backend and configures JAX precision and memory allocation behavior.
"""

import glob
import os
import pickle
import random
import warnings

os.environ["KERAS_BACKEND"] = "jax"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.7"

import jax

# Enable JAX float64 precision natively
jax.config.update("jax_enable_x64", True)

import jax.numpy as jnp
import keras
from keras import callbacks, layers, regularizers
import numpy as np
import polars as pl

warnings.filterwarnings("ignore")

# Show enough digits to round-trip float64 diagnostics
np.set_printoptions(precision=17, floatmode="unique")

# Set seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)

print(f"Keras version : {keras.__version__}")
print(f"Keras backend : {keras.backend.backend()}")
print(f"Working dir   : {os.getcwd()}")
# Out:
# 2026-08-04 03:48:14.050390: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1785804494.064808   74353 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1785804494.069259   74353 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Keras version : 3.12.0
# Keras backend : jax
# Working dir   : /home/samer/Documents/competitions/ROGII/notebooks

# %%
def find_data_dir() -> str:
    """Searches common Kaggle and local mount points for the ROGII dataset.

    Returns:
        str: Path to the dataset directory containing 'train' subdirectory.

    Raises:
        FileNotFoundError: If the dataset cannot be found in any candidate path.
    """
    candidates = [
        "/kaggle/input/competitions/rogii-wellbore-geology-prediction",
        "/kaggle/input/rogii-wellbore-geology-prediction",
        "/home/samer/Documents/competitions/ROGII/dataset",
    ]

    for scan_root in ["/kaggle/input", "/kaggle/input/competitions"]:
        if os.path.isdir(scan_root):
            for entry in os.listdir(scan_root):
                full = os.path.join(scan_root, entry)
                if os.path.isdir(full) and full not in candidates:
                    candidates.append(full)

    print("Searching for ROGII dataset...")
    for path in candidates:
        if not os.path.isdir(path):
            continue

        contents = os.listdir(path)
        has_train = "train" in contents and os.path.isdir(os.path.join(path, "train"))
        n_train = 0
        if has_train:
            n_train = len(
                glob.glob(os.path.join(path, "train", "*__horizontal_well.csv"))
            )

        if n_train > 0:
            print(f"  V Using {path} (found {n_train} train wells)")
            return path

    raise FileNotFoundError("Could not find ROGII dataset.")


DATA_DIR = find_data_dir()
# Out:
# Searching for ROGII dataset...
#   V Using /home/samer/Documents/competitions/ROGII/dataset (found 773 train wells)

# %% [markdown]
# ### Data preparation

# %%
"""Data loading, preprocessing and preparation functions using Polars and JAX.

The Conv1D model is trained with a test-like TVT_input mask. In the competition test
wells, TVT_input is known before the submission interval and missing throughout the
interval that must be predicted. If validation keeps the true TVT_input, the model can
learn an identity shortcut and report unrealistically low validation RMSE.
"""

from typing import Dict, List, Tuple, Union
import glob
import os
import pickle
import jax
import jax.numpy as jnp
import numpy as np
import polars as pl

# Define the full list of 14 engineered features plus the 6 base features.
FEATURE_COLS: List[str] = [
    "MD", "X", "Y", "Z", "GR", "TVT_input", # Base features
    # Trajectory & Geometry (5)
    "inclination", "dZ_dMD", "dX_dMD", "dY_dMD", "horizontal_displacement",
    # Multi-Scale GR Context (6)
    "GR_mean_10", "GR_std_10",
    "GR_mean_50", "GR_std_50",
    "GR_mean_100", "GR_std_100",
    # Stratigraphic Positioning (3)
    # "dist_to_buda", "dist_to_egfdl", "dist_to_astnl" # Removed: Not available in test set
]

# Base features required for preprocessing and feature engineering.
# Includes all geological markers needed for distance calculations.
BASE_FEATURE_COLS: List[str] = [
    "MD", "X", "Y", "Z", "GR", "TVT_input",
    "ANCC", "ASTNU", "ASTNL", "EGFDU", "EGFDL", "BUDA"
]
TARGET: str = "TVT"
TVT_INPUT_COL: str = "TVT_input"
MASK_START_RATIO_RANGE: Tuple[float, float] = (0.20, 0.40)


def mask_tvt_input_for_prediction_zone(
    df: pl.DataFrame,
    rng: np.random.Generator,
    ratio_range: Tuple[float, float] = MASK_START_RATIO_RANGE,
) -> Tuple[pl.DataFrame, int]:
    """Masks a suffix of TVT_input to mimic the hidden test prediction interval.

    Args:
        df (pl.DataFrame): Input DataFrame containing the well data.
        rng (np.random.Generator): Random number generator for reproducibility.
        ratio_range (Tuple[float, float]): Range of mask start ratio relative
          to well depth.

    Returns:
        Tuple[pl.DataFrame, int]: A tuple containing the masked DataFrame and
          the index where the masking started.
    """
    if TVT_INPUT_COL not in df.columns or len(df) < 2:
        return df, len(df)

    low, high = ratio_range
    mask_start = int(round(len(df) * rng.uniform(low, high)))
    mask_start = min(max(mask_start, 1), len(df) - 1)
    row_nr = pl.int_range(0, pl.len())
    df = df.with_columns(
        pl.when(row_nr >= mask_start)
        .then(None)
        .otherwise(pl.col(TVT_INPUT_COL))
        .alias(TVT_INPUT_COL)
    )
    return df, mask_start


def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    """Interpolates nulls and engineers an extensive set of 14 features.

    Args:
        df (pl.DataFrame): Input DataFrame with missing values.

    Returns:
        pl.DataFrame: Preprocessed DataFrame with all feature columns filled.
    """
    # 1. Interpolate base features and markers first
    for col in BASE_FEATURE_COLS:
        if col in df.columns:
            df = df.with_columns(
                pl.col(col)
                .interpolate()
                .fill_null(strategy="forward")
                .fill_null(strategy="backward")
                .fill_null(0.0) # Final fill for any remaining nulls
            )

    # 2. Engineer the 14 new features
    df = df.with_columns(
        # Trajectory & Geometry
        ((pl.col("Z").diff().fill_null(0)) / (pl.col("MD").diff().fill_null(1e-6)))
        .clip(-1.0, 1.0)
        .map_elements(np.arcsin, return_dtype=pl.Float64).alias("inclination"),
        (pl.col("Z").diff().fill_null(0) / pl.col("MD").diff().fill_null(1e-6)).alias("dZ_dMD"),
        (pl.col("X").diff().fill_null(0) / pl.col("MD").diff().fill_null(1e-6)).alias("dX_dMD"),
        (pl.col("Y").diff().fill_null(0) / pl.col("MD").diff().fill_null(1e-6)).alias("dY_dMD"),
        ((pl.col("X").diff().fill_null(0)**2) + (pl.col("Y").diff().fill_null(0)**2)).sqrt().cum_sum().alias("horizontal_displacement"),
        
        # Multi-Scale GR Context
        pl.col("GR").rolling_mean(window_size=10).alias("GR_mean_10"),
        pl.col("GR").rolling_std(window_size=10).alias("GR_std_10"),
        pl.col("GR").rolling_mean(window_size=50).alias("GR_mean_50"),
        pl.col("GR").rolling_std(window_size=50).alias("GR_std_50"),
        pl.col("GR").rolling_mean(window_size=100).alias("GR_mean_100"),
        pl.col("GR").rolling_std(window_size=100).alias("GR_std_100"),

        # Stratigraphic Positioning features removed as markers are not in test data
    )

    # 3. Fill nulls generated by rolling windows and diffs
    return df.with_columns(
        pl.all().forward_fill().backward_fill().fill_null(0.0)
    )


def prepare_data(
    data_dir: str,
    val_ratio: float = 0.20,
    seed: int = 42,
    max_wells: Union[int, None] = None,
) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
    """Loads wells and builds train/validation arrays with test-like masking.

    Reshapes the inputs to 3D tensors compatible with Conv1D layers and uses JAX
    on CPU memory for double-precision normalization to avoid GPU OOM.

    Args:
        data_dir (str): Path to the training dataset.
        val_ratio (float): Fraction of wells to use for validation.
        seed (int): Random seed for split and masking reproducibility.
        max_wells (Union[int, None]): Maximum number of wells to load (for debugging).

    Returns:
        Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
          A tuple containing:
            - X_train: Preprocessed standardized training features (3D: [samples, 1, features]).
            - y_train: Standardized training target values (1D: [samples]).
            - X_val: Preprocessed standardized validation features (3D: [samples, 1, features]).
            - y_val: Standardized validation target values (1D: [samples]).
            - y_val_raw: Raw validation targets in original scale (1D: [samples]).
            - scaler: Dictionary containing standardization scaling parameters.
    """
    dataset_root = os.path.dirname(data_dir)

    # 1. Get original training IDs
    pattern_train = os.path.join(data_dir, "train", "*__horizontal_well.csv")
    files_train = sorted([os.path.basename(f) for f in glob.glob(pattern_train)])

    # 2. Get augmented training files
    # pattern_aug = os.path.join(
    #     dataset_root, "dataset_augmented", "train", "*__horizontal_well_aug.csv"
    # )
    # files_aug = sorted([os.path.basename(f) for f in glob.glob(pattern_aug)])

    # Combined training file list
    files_train_all = files_train #+ files_aug

    if max_wells:
        files_train_all = files_train_all[:max_wells]

    rng = np.random.default_rng(seed)
    n_val = max(1, int(len(files_train_all) * val_ratio))
    val_set = set(rng.permutation(len(files_train_all))[:n_val])

    train_files = [fname for i, fname in enumerate(files_train_all) if i not in val_set]
    val_files = [fname for i, fname in enumerate(files_train_all) if i in val_set]

    print(
        f"Loading {len(files_train_all)} training wells total. "
        # f"(Original: {len(files_train)}, Augmented: {len(files_aug)})."
    )

    def get_arrays(files: List[str], split_name: str) -> Tuple[np.ndarray, np.ndarray]:
        """Reads CSV files for a split, masks TVT_input, and returns merged arrays.

        Args:
            files (List[str]): List of filenames to load.
            split_name (str): Label for the dataset split (e.g. "Train", "Val").

        Returns:
            Tuple[np.ndarray, np.ndarray]: Merged features and target arrays.
        """
        feats, tgts, mask_starts = [], [], []
        for filename in files:
            try:
                # if filename in files_aug:
                #     path = os.path.join(
                #         dataset_root, "dataset_augmented", "train", filename
                #     )
                # else:
                path = os.path.join(data_dir, "train", filename)

                df = pl.read_csv(path, infer_schema_length=10000)
                df = df.filter(pl.col(TARGET).is_not_null())
                if len(df) == 0:
                    continue

                df, mask_start = mask_tvt_input_for_prediction_zone(df, rng)
                df = preprocess(df)

                feats.append(df.select(FEATURE_COLS).to_numpy().astype(np.float64))
                tgts.append(df.select(TARGET).to_numpy().ravel().astype(np.float64))
                mask_starts.append(mask_start / len(df))
            except Exception as e:
                print(f"  Skip {filename}: {e}")

        if not feats:
            raise ValueError(f"No usable wells found for {split_name} split.")

        print(
            f"{split_name} TVT_input mask start ratio: "
            f"mean={np.mean(mask_starts):.3f}, "
            f"min={np.min(mask_starts):.3f}, max={np.max(mask_starts):.3f}"
        )
        return np.concatenate(feats), np.concatenate(tgts)

    X_train_raw, y_train_raw = get_arrays(train_files, "Train")
    X_val_raw, y_val_raw = get_arrays(val_files, "Val")

    cpu_dev = jax.devices("cpu")[0]
    X_tr_jax = jax.device_put(X_train_raw, cpu_dev)
    y_tr_jax = jax.device_put(y_train_raw, cpu_dev)
    X_val_jax = jax.device_put(X_val_raw, cpu_dev)
    y_val_jax = jax.device_put(y_val_raw, cpu_dev)

    feat_mean = jnp.mean(X_tr_jax, axis=0)
    feat_std = jnp.std(X_tr_jax, axis=0)
    feat_std = jnp.where(feat_std == 0, 1.0, feat_std)

    target_mean = jnp.mean(y_tr_jax)
    target_std = jnp.std(y_tr_jax)
    target_std = jnp.where(target_std == 0, 1.0, target_std)

    X_train_n = (X_tr_jax - feat_mean) / feat_std
    y_train_n = (y_tr_jax - target_mean) / target_std
    X_val_n = (X_val_jax - feat_mean) / feat_std
    y_val_n = (y_val_jax - target_mean) / target_std

    scaler = {
        "feature_cols": FEATURE_COLS,
        "feat_mean": np.array(feat_mean),
        "feat_std": np.array(feat_std),
        "target_mean": float(target_mean),
        "target_std": float(target_std),
        "normalized": True,
        "tvt_input_masked_for_training": True,
        "mask_start_ratio_range": MASK_START_RATIO_RANGE,
    }

    # Reshape features to 3D format (samples, sequence_length=1, features) for Conv1D compatibility
    X_train_3d = np.array(X_train_n, dtype=np.float32).reshape(-1, 1, len(FEATURE_COLS))
    X_val_3d = np.array(X_val_n, dtype=np.float32).reshape(-1, 1, len(FEATURE_COLS))

    return (
        X_train_3d,
        np.array(y_train_n, dtype=np.float32),
        X_val_3d,
        np.array(y_val_n, dtype=np.float32),
        y_val_raw,
        scaler,
    )


print("Preparing dataset...")
X_train, y_train, X_val, y_val, y_val_raw, scaler = prepare_data(DATA_DIR)
print(f"Train size: {X_train.shape}, Val size: {X_val.shape}")

print(X_train[0:10], y_train[0:10])

OUT_DIR = "../outputs"
os.makedirs(OUT_DIR, exist_ok=True)
scaler_path = os.path.join(OUT_DIR, "conv_tr_scaler_params_v4.pkl")
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)
print(f"Scaler parameters saved to {scaler_path}")
# Out:
# Preparing dataset...
# Loading 773 training wells total.
# Train TVT_input mask start ratio: mean=0.301, min=0.200, max=0.400
# Val TVT_input mask start ratio: mean=0.295, min=0.200, max=0.399
# Train size: (4074081, 1, 17), Val size: (1018174, 1, 17)
# [[[-1.2392433    0.9576023    0.27120844  -0.11293809   0.45289207
#    -0.11013199   0.3546629    0.36765042   0.11812401  -0.12272629
#    -1.4332181    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.2387862    0.9576023    0.27120817  -0.11454501   0.5087848
#    -0.108473636 -3.8152466   -3.2101798    0.11812401  -0.13520269
#    -1.4332134    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.238329     0.9576023    0.27120787  -0.11615194   0.6025817
#    -0.106815286 -3.8152466   -3.2101798    0.11812401  -0.13520269
#    -1.4332086    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.237872     0.9576023    0.2712076   -0.117758855  0.40535113
#    -0.10515694  -3.8152466   -3.2101798    0.11812401  -0.13520269
#    -1.4332038    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.237415     0.9576023    0.2712073   -0.119365774  0.20812057
#    -0.10351454  -3.8152466   -3.2101798    0.11812401  -0.13520269
#    -1.4331989    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.2369579    0.9576023    0.27120703  -0.12097269   0.37644112
#    -0.10187214  -3.8152466   -3.2101798    0.11812401  -0.13520269
#    -1.4331942    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.2365009    0.9576023    0.27120674  -0.12257961   0.5768839
#    -0.10024568  -3.8152466   -3.2101798    0.11812401  -0.13520269
#    -1.4331894    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.2360438    0.9576023    0.27120674  -0.12418653   0.36038
#    -0.09861922  -3.8152466   -3.2101798    0.11812401  -0.12272629
#    -1.4331894    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.2355868    0.9576021    0.27120647  -0.12579346   0.22353923
#    -0.09699277  -3.8152466   -3.2101798    0.09834253  -0.13520269
#    -1.4331826    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]
#
#  [[-1.2351297    0.9576021    0.27120647  -0.12740037   0.371944
#    -0.09538225  -3.8152466   -3.2101798    0.11812401  -0.12272629
#    -1.4331826    0.42080754  -0.399097     0.7057549    1.3283666
#     0.5954099    0.3984342  ]]] [-0.11273977 -0.11108175 -0.10942373 -0.1077657  -0.10612362 -0.10448153
#  -0.10285539 -0.10122925 -0.09960312 -0.09799291]
# Scaler parameters saved to ../outputs/conv_tr_scaler_params_v4.pkl

# %% [markdown]
# ### Model building

# %%
"""Model construction and compilation for Conv1D architecture."""

input_dim = len(FEATURE_COLS)
activation = layers.LeakyReLU(negative_slope=0.5)
initializer = "glorot_normal"
kr_rate = 5e-05
num_layers = 2

# Functional API for residual connections
inputs = keras.Input(shape=(1, input_dim))
x = inputs

# Initial Conv1D to project input to 64 filters
x = layers.Conv1D(
    filters=32,
    kernel_size=1,  # Use kernel size 1 for projection
    padding="causal",
    kernel_initializer=initializer,
)(x)

# Stack of residual blocks
for _ in range(num_layers):
    residual = x
    x = layers.Conv1D(
        filters=32,
        kernel_size=16,
        activation=activation,
        kernel_initializer=initializer,
        kernel_regularizer=regularizers.l2(kr_rate),
        padding="causal",
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.add([x, residual])  # Add the residual connection

x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="linear")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# Optimizer configuration
optimizer = keras.optimizers.AdamW(
    learning_rate=5e-05,
    weight_decay=1e-04,
    # momentum = 0.999,
    # beta_1=0.9,
    # beta_2=0.999,
    # amsgrad=False,
    global_clipnorm=1.0,
    use_ema=True,
    ema_momentum=0.9,
)

model.compile(
    optimizer=optimizer,
    loss="huber",
    metrics=[keras.metrics.RootMeanSquaredError(name="rmse")],
)

print("Conv1D model built and compiled successfully.")
model.summary()
# Out:
# Conv1D model built and compiled successfully.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1, 17)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 1, 32)     │        576 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 1, 32)     │     16,416 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1, 32)     │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1, 32)     │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 32)     │          0 │ dropout[0][0],    │
# │                     │                   │            │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 1, 32)     │     16,416 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 32)     │        128 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 32)     │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 32)     │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 32)        │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │         33 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 33,697 (131.63 KB)
#  Trainable params: 33,569 (131.13 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# ### Training

# %%
"""Train the Conv1D model with ModelCheckpoint, ReduceLROnPlateau, and EarlyStopping."""

OUT_DIR = "../outputs"
os.makedirs(OUT_DIR, exist_ok=True)
best_model_path = os.path.join(OUT_DIR, "trained_conv1d_model_augmented_v5.keras")

cbs = [
    callbacks.ModelCheckpoint(
        best_model_path, monitor="val_rmse", save_best_only=True, mode="min"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_rmse", factor=0.5, patience=100, min_lr=3e-7
    ),
    # callbacks.EarlyStopping(monitor="val_rmse", patience=15, restore_best_weights=True),
]

print("Starting training of the Conv1D model...")
history = model.fit(
    X_train,
    y_train,
    epochs=4000,
    validation_data=(X_val, y_val),
    batch_size=1024,
    callbacks=cbs,
)
# Out:
# Starting training of the Conv1D model...
# Epoch 1/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.1278 - rmse: 0.5806 - val_loss: 0.0017 - val_rmse: 0.0547 - learning_rate: 5.0000e-05
# Epoch 2/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0299 - rmse: 0.3059 - val_loss: 7.7857e-04 - val_rmse: 0.0348 - learning_rate: 5.0000e-05
# Epoch 3/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0112 - rmse: 0.1770 - val_loss: 5.5729e-04 - val_rmse: 0.0284 - learning_rate: 5.0000e-05
# Epoch 4/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0030 - rmse: 0.0764 - val_loss: 4.1443e-04 - val_rmse: 0.0239 - learning_rate: 5.0000e-05
# Epoch 5/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 9.6742e-04 - rmse: 0.0414 - val_loss: 3.8540e-04 - val_rmse: 0.0241 - learning_rate: 5.0000e-05
# Epoch 6/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 5.8490e-04 - rmse: 0.0317 - val_loss: 3.5972e-04 - val_rmse: 0.0239 - learning_rate: 5.0000e-05
# Epoch 7/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 4.5415e-04 - rmse: 0.0278 - val_loss: 3.4795e-04 - val_rmse: 0.0239 - learning_rate: 5.0000e-05
# Epoch 8/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 4.0451e-04 - rmse: 0.0263 - val_loss: 3.3749e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 9/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.7949e-04 - rmse: 0.0255 - val_loss: 3.3398e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-05
# Epoch 10/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 3.6361e-04 - rmse: 0.0251 - val_loss: 3.2847e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 11/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.5250e-04 - rmse: 0.0248 - val_loss: 3.2574e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-05
# Epoch 12/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.4431e-04 - rmse: 0.0246 - val_loss: 3.1921e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 13/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.3827e-04 - rmse: 0.0245 - val_loss: 3.1559e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 14/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.3264e-04 - rmse: 0.0244 - val_loss: 3.1467e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 15/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.2793e-04 - rmse: 0.0243 - val_loss: 3.1094e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 16/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.2359e-04 - rmse: 0.0242 - val_loss: 3.0816e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 17/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.1931e-04 - rmse: 0.0242 - val_loss: 3.0369e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 18/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.1538e-04 - rmse: 0.0241 - val_loss: 3.0052e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 19/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.1055e-04 - rmse: 0.0241 - val_loss: 2.9909e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 20/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.0587e-04 - rmse: 0.0240 - val_loss: 2.9221e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 21/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 3.0248e-04 - rmse: 0.0240 - val_loss: 2.9651e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-05
# Epoch 22/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.9965e-04 - rmse: 0.0240 - val_loss: 2.9049e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 23/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.9760e-04 - rmse: 0.0239 - val_loss: 2.8481e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 24/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.9546e-04 - rmse: 0.0239 - val_loss: 2.8656e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 25/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.9367e-04 - rmse: 0.0239 - val_loss: 2.9539e-04 - val_rmse: 0.0240 - learning_rate: 5.0000e-05
# Epoch 26/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.9211e-04 - rmse: 0.0239 - val_loss: 2.9021e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-05
# Epoch 27/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.9093e-04 - rmse: 0.0239 - val_loss: 2.8299e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 28/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8995e-04 - rmse: 0.0238 - val_loss: 2.8157e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 29/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8917e-04 - rmse: 0.0238 - val_loss: 2.8305e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 30/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8842e-04 - rmse: 0.0238 - val_loss: 2.8434e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 31/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8784e-04 - rmse: 0.0238 - val_loss: 2.8460e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 32/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8724e-04 - rmse: 0.0238 - val_loss: 2.8142e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 33/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8678e-04 - rmse: 0.0238 - val_loss: 2.8337e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 34/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8640e-04 - rmse: 0.0238 - val_loss: 2.8322e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 35/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8599e-04 - rmse: 0.0238 - val_loss: 2.8247e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 36/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8573e-04 - rmse: 0.0238 - val_loss: 2.8027e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 37/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8537e-04 - rmse: 0.0238 - val_loss: 2.7968e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 38/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8505e-04 - rmse: 0.0237 - val_loss: 2.8181e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 39/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8480e-04 - rmse: 0.0237 - val_loss: 2.8019e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 40/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8454e-04 - rmse: 0.0237 - val_loss: 2.8249e-04 - val_rmse: 0.0237 - learning_rate: 5.0000e-05
# Epoch 41/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8433e-04 - rmse: 0.0237 - val_loss: 2.8083e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 42/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8403e-04 - rmse: 0.0237 - val_loss: 2.7812e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 43/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8382e-04 - rmse: 0.0237 - val_loss: 2.8069e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 44/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8352e-04 - rmse: 0.0237 - val_loss: 2.7815e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 45/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8327e-04 - rmse: 0.0237 - val_loss: 2.7820e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 46/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8301e-04 - rmse: 0.0237 - val_loss: 2.7911e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 47/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8276e-04 - rmse: 0.0237 - val_loss: 2.7953e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 48/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8240e-04 - rmse: 0.0237 - val_loss: 2.7775e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 49/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8206e-04 - rmse: 0.0237 - val_loss: 2.7833e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 50/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8181e-04 - rmse: 0.0237 - val_loss: 2.8087e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 51/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8153e-04 - rmse: 0.0237 - val_loss: 2.7711e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 52/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8136e-04 - rmse: 0.0237 - val_loss: 2.7694e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 53/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8101e-04 - rmse: 0.0237 - val_loss: 2.7775e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 54/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8087e-04 - rmse: 0.0237 - val_loss: 2.7620e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 55/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8074e-04 - rmse: 0.0237 - val_loss: 2.7636e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 56/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8062e-04 - rmse: 0.0237 - val_loss: 2.7641e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 57/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8047e-04 - rmse: 0.0237 - val_loss: 2.7832e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 58/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8043e-04 - rmse: 0.0237 - val_loss: 2.7705e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 59/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8034e-04 - rmse: 0.0237 - val_loss: 2.7712e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 60/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8025e-04 - rmse: 0.0237 - val_loss: 2.7961e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 61/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8026e-04 - rmse: 0.0237 - val_loss: 2.7661e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 62/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8020e-04 - rmse: 0.0237 - val_loss: 2.7653e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 63/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8018e-04 - rmse: 0.0237 - val_loss: 2.7734e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 64/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8019e-04 - rmse: 0.0237 - val_loss: 2.7674e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 65/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8015e-04 - rmse: 0.0237 - val_loss: 2.7687e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 66/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8021e-04 - rmse: 0.0237 - val_loss: 2.7827e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 67/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8011e-04 - rmse: 0.0237 - val_loss: 2.7710e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 68/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8011e-04 - rmse: 0.0237 - val_loss: 2.7490e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 69/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8013e-04 - rmse: 0.0237 - val_loss: 2.7566e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 70/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8017e-04 - rmse: 0.0237 - val_loss: 2.7837e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 71/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8018e-04 - rmse: 0.0237 - val_loss: 2.7619e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 72/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8021e-04 - rmse: 0.0237 - val_loss: 2.7701e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 73/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8011e-04 - rmse: 0.0237 - val_loss: 2.7589e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 74/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8011e-04 - rmse: 0.0237 - val_loss: 2.7688e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 75/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8010e-04 - rmse: 0.0237 - val_loss: 2.7716e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 76/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8010e-04 - rmse: 0.0237 - val_loss: 2.7511e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 77/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8006e-04 - rmse: 0.0237 - val_loss: 2.7647e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 78/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8006e-04 - rmse: 0.0237 - val_loss: 2.7640e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 79/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8008e-04 - rmse: 0.0237 - val_loss: 2.7795e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 80/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8005e-04 - rmse: 0.0237 - val_loss: 2.7469e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 81/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8005e-04 - rmse: 0.0237 - val_loss: 2.7754e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 82/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8011e-04 - rmse: 0.0237 - val_loss: 2.7584e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 83/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8007e-04 - rmse: 0.0237 - val_loss: 2.7556e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 84/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8002e-04 - rmse: 0.0237 - val_loss: 2.7637e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 85/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8010e-04 - rmse: 0.0237 - val_loss: 2.7573e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 86/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8006e-04 - rmse: 0.0237 - val_loss: 2.7535e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 87/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8008e-04 - rmse: 0.0237 - val_loss: 2.7662e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 88/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7998e-04 - rmse: 0.0236 - val_loss: 2.7655e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 89/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8002e-04 - rmse: 0.0237 - val_loss: 2.7620e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 90/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8003e-04 - rmse: 0.0237 - val_loss: 2.7698e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 91/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8000e-04 - rmse: 0.0236 - val_loss: 2.7599e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 92/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8006e-04 - rmse: 0.0237 - val_loss: 2.7572e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 93/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8000e-04 - rmse: 0.0236 - val_loss: 2.7678e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 94/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7998e-04 - rmse: 0.0236 - val_loss: 2.7570e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 95/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7998e-04 - rmse: 0.0236 - val_loss: 2.7688e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 96/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7998e-04 - rmse: 0.0236 - val_loss: 2.7618e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 97/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7994e-04 - rmse: 0.0236 - val_loss: 2.7650e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 98/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7996e-04 - rmse: 0.0236 - val_loss: 2.7469e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 99/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7996e-04 - rmse: 0.0236 - val_loss: 2.7568e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 100/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7996e-04 - rmse: 0.0236 - val_loss: 2.7608e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 101/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8001e-04 - rmse: 0.0237 - val_loss: 2.7472e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 102/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7994e-04 - rmse: 0.0236 - val_loss: 2.7628e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 103/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8000e-04 - rmse: 0.0237 - val_loss: 2.7598e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 104/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7996e-04 - rmse: 0.0236 - val_loss: 2.7670e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 105/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7994e-04 - rmse: 0.0236 - val_loss: 2.7646e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 106/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.8002e-04 - rmse: 0.0237 - val_loss: 2.7701e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 107/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7996e-04 - rmse: 0.0236 - val_loss: 2.7449e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 108/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7994e-04 - rmse: 0.0236 - val_loss: 2.7509e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 109/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7995e-04 - rmse: 0.0236 - val_loss: 2.7556e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 110/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7995e-04 - rmse: 0.0236 - val_loss: 2.7566e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 111/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7991e-04 - rmse: 0.0236 - val_loss: 2.7537e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 112/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7994e-04 - rmse: 0.0236 - val_loss: 2.7642e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 113/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7996e-04 - rmse: 0.0236 - val_loss: 2.7475e-04 - val_rmse: 0.0234 - learning_rate: 5.0000e-05
# Epoch 114/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7997e-04 - rmse: 0.0236 - val_loss: 2.7626e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 115/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7995e-04 - rmse: 0.0236 - val_loss: 2.7639e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 116/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7992e-04 - rmse: 0.0236 - val_loss: 2.7627e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 117/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7998e-04 - rmse: 0.0236 - val_loss: 2.7839e-04 - val_rmse: 0.0236 - learning_rate: 5.0000e-05
# Epoch 118/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7991e-04 - rmse: 0.0236 - val_loss: 2.7569e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 119/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7993e-04 - rmse: 0.0236 - val_loss: 2.7726e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 120/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7995e-04 - rmse: 0.0236 - val_loss: 2.7676e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 121/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7989e-04 - rmse: 0.0236 - val_loss: 2.7592e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 122/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7994e-04 - rmse: 0.0236 - val_loss: 2.7575e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 123/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7991e-04 - rmse: 0.0236 - val_loss: 2.7738e-04 - val_rmse: 0.0235 - learning_rate: 5.0000e-05
# Epoch 124/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7955e-04 - rmse: 0.0236 - val_loss: 2.7549e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 125/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7953e-04 - rmse: 0.0236 - val_loss: 2.7607e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 126/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7957e-04 - rmse: 0.0236 - val_loss: 2.7593e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 127/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7950e-04 - rmse: 0.0236 - val_loss: 2.7519e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 128/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7948e-04 - rmse: 0.0236 - val_loss: 2.7549e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 129/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7950e-04 - rmse: 0.0236 - val_loss: 2.7800e-04 - val_rmse: 0.0236 - learning_rate: 2.5000e-05
# Epoch 130/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7952e-04 - rmse: 0.0236 - val_loss: 2.7717e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 131/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7948e-04 - rmse: 0.0236 - val_loss: 2.7595e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 132/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7951e-04 - rmse: 0.0236 - val_loss: 2.7530e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 133/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7939e-04 - rmse: 0.0236 - val_loss: 2.7493e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 134/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7945e-04 - rmse: 0.0236 - val_loss: 2.7381e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 135/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7949e-04 - rmse: 0.0236 - val_loss: 2.7585e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 136/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7942e-04 - rmse: 0.0236 - val_loss: 2.7442e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 137/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7946e-04 - rmse: 0.0236 - val_loss: 2.7486e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 138/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7945e-04 - rmse: 0.0236 - val_loss: 2.7529e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 139/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7948e-04 - rmse: 0.0236 - val_loss: 2.7574e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 140/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7943e-04 - rmse: 0.0236 - val_loss: 2.7445e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 141/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7938e-04 - rmse: 0.0236 - val_loss: 2.7686e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 142/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7948e-04 - rmse: 0.0236 - val_loss: 2.7512e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 143/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7940e-04 - rmse: 0.0236 - val_loss: 2.7536e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 144/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7943e-04 - rmse: 0.0236 - val_loss: 2.7476e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 145/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7937e-04 - rmse: 0.0236 - val_loss: 2.7682e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 146/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7942e-04 - rmse: 0.0236 - val_loss: 2.7544e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 147/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7932e-04 - rmse: 0.0236 - val_loss: 2.7513e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 148/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7936e-04 - rmse: 0.0236 - val_loss: 2.7620e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 149/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7935e-04 - rmse: 0.0236 - val_loss: 2.7588e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 150/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7937e-04 - rmse: 0.0236 - val_loss: 2.7410e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 151/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7931e-04 - rmse: 0.0236 - val_loss: 2.7551e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 152/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7937e-04 - rmse: 0.0236 - val_loss: 2.7609e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 153/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7934e-04 - rmse: 0.0236 - val_loss: 2.7402e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 154/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7938e-04 - rmse: 0.0236 - val_loss: 2.7482e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 155/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7934e-04 - rmse: 0.0236 - val_loss: 2.7540e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 156/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7931e-04 - rmse: 0.0236 - val_loss: 2.7533e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 157/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7933e-04 - rmse: 0.0236 - val_loss: 2.7589e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 158/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7931e-04 - rmse: 0.0236 - val_loss: 2.7566e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 159/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7935e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 160/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7931e-04 - rmse: 0.0236 - val_loss: 2.7510e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 161/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7933e-04 - rmse: 0.0236 - val_loss: 2.7545e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 162/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7932e-04 - rmse: 0.0236 - val_loss: 2.7520e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 163/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7926e-04 - rmse: 0.0236 - val_loss: 2.7485e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 164/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7929e-04 - rmse: 0.0236 - val_loss: 2.7425e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 165/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7431e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 166/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7930e-04 - rmse: 0.0236 - val_loss: 2.7466e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 167/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7930e-04 - rmse: 0.0236 - val_loss: 2.7596e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 168/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7928e-04 - rmse: 0.0236 - val_loss: 2.7522e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 169/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7926e-04 - rmse: 0.0236 - val_loss: 2.7598e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 170/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7929e-04 - rmse: 0.0236 - val_loss: 2.7537e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 171/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7933e-04 - rmse: 0.0236 - val_loss: 2.7644e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 172/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7931e-04 - rmse: 0.0236 - val_loss: 2.7541e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 173/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7929e-04 - rmse: 0.0236 - val_loss: 2.7537e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 174/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7928e-04 - rmse: 0.0236 - val_loss: 2.7388e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 175/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7929e-04 - rmse: 0.0236 - val_loss: 2.7596e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 176/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7928e-04 - rmse: 0.0236 - val_loss: 2.7658e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 177/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7927e-04 - rmse: 0.0236 - val_loss: 2.7431e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 178/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7569e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 179/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7928e-04 - rmse: 0.0236 - val_loss: 2.7507e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 180/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7927e-04 - rmse: 0.0236 - val_loss: 2.7541e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 181/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7495e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 182/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7921e-04 - rmse: 0.0236 - val_loss: 2.7573e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 183/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7928e-04 - rmse: 0.0236 - val_loss: 2.7567e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 184/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7922e-04 - rmse: 0.0236 - val_loss: 2.7483e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 185/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7429e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 186/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7928e-04 - rmse: 0.0236 - val_loss: 2.7484e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 187/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7922e-04 - rmse: 0.0236 - val_loss: 2.7535e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 188/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7927e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 189/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7563e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 190/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7929e-04 - rmse: 0.0236 - val_loss: 2.7428e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 191/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7926e-04 - rmse: 0.0236 - val_loss: 2.7519e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 192/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7515e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 193/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7922e-04 - rmse: 0.0236 - val_loss: 2.7634e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 194/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7926e-04 - rmse: 0.0236 - val_loss: 2.7487e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 195/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7924e-04 - rmse: 0.0236 - val_loss: 2.7656e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 196/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7924e-04 - rmse: 0.0236 - val_loss: 2.7581e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 197/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7462e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 198/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7920e-04 - rmse: 0.0236 - val_loss: 2.7629e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 199/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7441e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 200/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7495e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 201/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7562e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 202/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7623e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 203/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7929e-04 - rmse: 0.0236 - val_loss: 2.7537e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 204/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7924e-04 - rmse: 0.0236 - val_loss: 2.7518e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 205/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7927e-04 - rmse: 0.0236 - val_loss: 2.7416e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 206/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7492e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 207/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7921e-04 - rmse: 0.0236 - val_loss: 2.7692e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 208/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7495e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 209/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7926e-04 - rmse: 0.0236 - val_loss: 2.7491e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 210/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7921e-04 - rmse: 0.0236 - val_loss: 2.7590e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 211/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7505e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 212/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7922e-04 - rmse: 0.0236 - val_loss: 2.7672e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 213/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7919e-04 - rmse: 0.0236 - val_loss: 2.7460e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 214/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7922e-04 - rmse: 0.0236 - val_loss: 2.7562e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 215/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7925e-04 - rmse: 0.0236 - val_loss: 2.7654e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 216/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7575e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 217/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7920e-04 - rmse: 0.0236 - val_loss: 2.7441e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 218/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7596e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 219/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7923e-04 - rmse: 0.0236 - val_loss: 2.7524e-04 - val_rmse: 0.0235 - learning_rate: 2.5000e-05
# Epoch 220/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7920e-04 - rmse: 0.0236 - val_loss: 2.7398e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 221/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7920e-04 - rmse: 0.0236 - val_loss: 2.7422e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 222/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7924e-04 - rmse: 0.0236 - val_loss: 2.7812e-04 - val_rmse: 0.0236 - learning_rate: 2.5000e-05
# Epoch 223/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7921e-04 - rmse: 0.0236 - val_loss: 2.7513e-04 - val_rmse: 0.0234 - learning_rate: 2.5000e-05
# Epoch 224/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7585e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 225/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7555e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 226/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7897e-04 - rmse: 0.0236 - val_loss: 2.7396e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 227/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7896e-04 - rmse: 0.0236 - val_loss: 2.7503e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 228/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7544e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 229/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7903e-04 - rmse: 0.0236 - val_loss: 2.7608e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 230/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7904e-04 - rmse: 0.0236 - val_loss: 2.7540e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 231/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7901e-04 - rmse: 0.0236 - val_loss: 2.7534e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 232/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7619e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 233/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7901e-04 - rmse: 0.0236 - val_loss: 2.7568e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 234/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7901e-04 - rmse: 0.0236 - val_loss: 2.7613e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 235/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7497e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 236/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7522e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 237/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7507e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 238/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7898e-04 - rmse: 0.0236 - val_loss: 2.7502e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 239/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7569e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 240/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7896e-04 - rmse: 0.0236 - val_loss: 2.7436e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 241/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7420e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 242/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7902e-04 - rmse: 0.0236 - val_loss: 2.7502e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 243/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7416e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 244/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7902e-04 - rmse: 0.0236 - val_loss: 2.7508e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 245/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7900e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 246/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7510e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 247/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7427e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 248/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7573e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 249/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7475e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 250/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7487e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 251/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7500e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 252/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7600e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 253/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7897e-04 - rmse: 0.0236 - val_loss: 2.7526e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 254/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7501e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 255/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7554e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 256/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7894e-04 - rmse: 0.0236 - val_loss: 2.7434e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 257/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7894e-04 - rmse: 0.0236 - val_loss: 2.7602e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 258/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7898e-04 - rmse: 0.0236 - val_loss: 2.7513e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 259/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7515e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 260/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7476e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 261/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7460e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 262/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7890e-04 - rmse: 0.0236 - val_loss: 2.7462e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 263/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7892e-04 - rmse: 0.0236 - val_loss: 2.7512e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 264/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7892e-04 - rmse: 0.0236 - val_loss: 2.7580e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 265/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7515e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 266/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7549e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 267/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7899e-04 - rmse: 0.0236 - val_loss: 2.7439e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 268/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7529e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 269/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7494e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 270/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7898e-04 - rmse: 0.0236 - val_loss: 2.7606e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 271/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7897e-04 - rmse: 0.0236 - val_loss: 2.7464e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 272/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7892e-04 - rmse: 0.0236 - val_loss: 2.7492e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 273/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7454e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 274/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7527e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 275/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7892e-04 - rmse: 0.0236 - val_loss: 2.7542e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 276/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7435e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 277/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7889e-04 - rmse: 0.0236 - val_loss: 2.7534e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 278/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7900e-04 - rmse: 0.0236 - val_loss: 2.7549e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 279/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7467e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 280/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7679e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 281/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7623e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 282/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7646e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 283/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7597e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 284/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7895e-04 - rmse: 0.0236 - val_loss: 2.7519e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 285/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7898e-04 - rmse: 0.0236 - val_loss: 2.7439e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 286/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7517e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 287/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7894e-04 - rmse: 0.0236 - val_loss: 2.7560e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 288/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7888e-04 - rmse: 0.0236 - val_loss: 2.7520e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 289/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7891e-04 - rmse: 0.0236 - val_loss: 2.7519e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 290/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7888e-04 - rmse: 0.0236 - val_loss: 2.7514e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 291/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7889e-04 - rmse: 0.0236 - val_loss: 2.7461e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 292/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7894e-04 - rmse: 0.0236 - val_loss: 2.7517e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 293/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7888e-04 - rmse: 0.0236 - val_loss: 2.7511e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 294/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7893e-04 - rmse: 0.0236 - val_loss: 2.7595e-04 - val_rmse: 0.0235 - learning_rate: 1.2500e-05
# Epoch 295/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7894e-04 - rmse: 0.0236 - val_loss: 2.7510e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 296/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 2.7890e-04 - rmse: 0.0236 - val_loss: 2.7395e-04 - val_rmse: 0.0234 - learning_rate: 1.2500e-05
# Epoch 297/4000
# ...
# Epoch 3904/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7446e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3905/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7443e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3906/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7453e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3907/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7461e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3908/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7436e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3909/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7464e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3910/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7460e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3911/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7441e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3912/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7436e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3913/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7434e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3914/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7445e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3915/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7447e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3916/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7453e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3917/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3918/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7461e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3919/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7841e-04 - rmse: 0.0236 - val_loss: 2.7470e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3920/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7433e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3921/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7448e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3922/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7840e-04 - rmse: 0.0236 - val_loss: 2.7438e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3923/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7448e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3924/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3925/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7456e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3926/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7855e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3927/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7455e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3928/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3929/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7460e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3930/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7471e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3931/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7853e-04 - rmse: 0.0236 - val_loss: 2.7441e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3932/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7436e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3933/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7424e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3934/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7454e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3935/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7439e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3936/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7854e-04 - rmse: 0.0236 - val_loss: 2.7465e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3937/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7441e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3938/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3939/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7852e-04 - rmse: 0.0236 - val_loss: 2.7443e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3940/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7852e-04 - rmse: 0.0236 - val_loss: 2.7458e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3941/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3942/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7464e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3943/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3944/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7440e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3945/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7429e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3946/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7434e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3947/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7450e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3948/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7458e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3949/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7437e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3950/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7426e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3951/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7438e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3952/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7435e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3953/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7454e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3954/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7456e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3955/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7449e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3956/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7452e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3957/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7437e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3958/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7852e-04 - rmse: 0.0236 - val_loss: 2.7477e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3959/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7852e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3960/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7430e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3961/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7459e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3962/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7839e-04 - rmse: 0.0236 - val_loss: 2.7446e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3963/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7447e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3964/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7461e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3965/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7441e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3966/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7450e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3967/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7447e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3968/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7429e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3969/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7436e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3970/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7462e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3971/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7854e-04 - rmse: 0.0236 - val_loss: 2.7450e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3972/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7844e-04 - rmse: 0.0236 - val_loss: 2.7462e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3973/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7853e-04 - rmse: 0.0236 - val_loss: 2.7445e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3974/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7456e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3975/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3976/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7845e-04 - rmse: 0.0236 - val_loss: 2.7432e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3977/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7448e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3978/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7847e-04 - rmse: 0.0236 - val_loss: 2.7445e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3979/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7458e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3980/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7435e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3981/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7447e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3982/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7437e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3983/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7446e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3984/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7449e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3985/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3986/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7453e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3987/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7450e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3988/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7844e-04 - rmse: 0.0236 - val_loss: 2.7446e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3989/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7456e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3990/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7844e-04 - rmse: 0.0236 - val_loss: 2.7438e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3991/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7852e-04 - rmse: 0.0236 - val_loss: 2.7451e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3992/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7851e-04 - rmse: 0.0236 - val_loss: 2.7456e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3993/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7846e-04 - rmse: 0.0236 - val_loss: 2.7450e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3994/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7443e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3995/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7843e-04 - rmse: 0.0236 - val_loss: 2.7446e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3996/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7848e-04 - rmse: 0.0236 - val_loss: 2.7444e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3997/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.7850e-04 - rmse: 0.0236 - val_loss: 2.7432e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3998/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7458e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 3999/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7844e-04 - rmse: 0.0236 - val_loss: 2.7464e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07
# Epoch 4000/4000
# 3979/3979 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.7849e-04 - rmse: 0.0236 - val_loss: 2.7448e-04 - val_rmse: 0.0234 - learning_rate: 3.0000e-07

# %% [markdown]
# ### Evaluation

# %%
"""Load the best model and evaluate its final RMSE on raw scale using JAX."""

# Denormalize using JAX on CPU device
cpu_dev = jax.devices("cpu")[0]
target_mean = jax.device_put(scaler["target_mean"], cpu_dev)
target_std = jax.device_put(scaler["target_std"], cpu_dev)
y_val_raw_jnp = jax.device_put(y_val_raw, cpu_dev)

# Predict on val set (normalized scale)
yp_n = model.predict(X_val, batch_size=128).ravel()
yp_n_jnp = jax.device_put(yp_n, cpu_dev)

# Denormalize predictions
yp_jnp = (yp_n_jnp * target_std) + target_mean

# Calculate error and RMSE using JAX
err = yp_jnp - y_val_raw_jnp
rmse = float(jnp.sqrt(jnp.mean(jnp.square(err))))
print(f"\nFinal Val RMSE (Optimized Conv1D Model, RAW SCALE): {rmse:.4f}")
# Out:
# 7955/7955 ━━━━━━━━━━━━━━━━━━━━ 5s 636us/step
#
# Final Val RMSE (Optimized Conv1D Model, RAW SCALE): 14.6930

# %%
"""Plots training and validation curves and saves them to the analytics directory."""

import matplotlib.pyplot as plt

ANALYTICS_DIR = "../analytics"
os.makedirs(ANALYTICS_DIR, exist_ok=True)


def plot_history(history):
    """Plots model loss and root mean squared error curves.

    Args:
        history: Keras History object.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Loss curve
    ax1.plot(history.history["loss"], label="Train")
    ax1.plot(history.history["val_loss"], label="Val")
    ax1.set_title("Conv1D Model Loss (MSE)")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.legend()
    ax1.grid(True)

    # RMSE curve
    ax2.plot(history.history["rmse"], label="Train")
    ax2.plot(history.history["val_rmse"], label="Val")
    ax2.set_title("Conv1D Model RMSE")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("RMSE")
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.savefig(os.path.join(ANALYTICS_DIR, "conv1d_training_history.png"))
    plt.show()


if "history" in locals():
    plot_history(history)

# %%
def plot_pred_vs_actual(y_true, y_pred, val_rmse):
    """Plots predicted vs actual values on raw scale and saves it to analytics."""
    plt.figure(figsize=(10, 6))
    plt.scatter(np.array(y_true), np.array(y_pred), alpha=0.1, s=1, color="blue")

    # Draw perfect prediction line
    min_val = min(float(y_true.min()), float(y_pred.min()))
    max_val = max(float(y_true.max()), float(y_pred.max()))
    plt.plot(
        [min_val, max_val], [min_val, max_val], "r--", lw=2, label="Perfect Prediction"
    )

    plt.title(f"Actual vs Predicted TVT (Val Set - Conv1D)\nRMSE: {val_rmse:.4f}")
    plt.xlabel("Actual TVT")
    plt.ylabel("Predicted TVT")
    plt.legend()
    plt.grid(True)

    plt.savefig(os.path.join(ANALYTICS_DIR, "conv1d_val_pred_vs_actual.png"))
    plt.show()


if "y_val_raw" in locals() and "yp_jnp" in locals():
    plot_pred_vs_actual(y_val_raw, yp_jnp, rmse)
