# %%
"""Environment setup and library imports for Conv1D training.

Sets Keras JAX backend and configures JAX precision and memory allocation behavior.
"""

import glob
import os
import pickle
import random
import warnings

os.environ["KERAS_BACKEND"] = "jax"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "0.7"

import jax

# Enable JAX float64 precision natively
jax.config.update("jax_enable_x64", True)

import jax.numpy as jnp
import keras
from keras import callbacks, layers, regularizers
import numpy as np
import polars as pl

warnings.filterwarnings("ignore")

# Show enough digits to round-trip float64 diagnostics
np.set_printoptions(precision=17, floatmode="unique")

# Set seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)

print(f"Keras version : {keras.__version__}")
print(f"Keras backend : {keras.backend.backend()}")
print(f"Working dir   : {os.getcwd()}")
# Out:
# 2026-07-25 17:43:13.777465: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1784990593.789126  437627 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1784990593.793213  437627 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Keras version : 3.12.0
# Keras backend : jax
# Working dir   : /home/samer/Documents/competitions/ROGII/notebooks

# %%
def find_data_dir() -> str:
    """Searches common Kaggle and local mount points for the ROGII dataset.

    Returns:
        str: Path to the dataset directory containing 'train' subdirectory.

    Raises:
        FileNotFoundError: If the dataset cannot be found in any candidate path.
    """
    candidates = [
        "/kaggle/input/competitions/rogii-wellbore-geology-prediction",
        "/kaggle/input/rogii-wellbore-geology-prediction",
        "/home/samer/Documents/competitions/ROGII/dataset",
    ]

    for scan_root in ["/kaggle/input", "/kaggle/input/competitions"]:
        if os.path.isdir(scan_root):
            for entry in os.listdir(scan_root):
                full = os.path.join(scan_root, entry)
                if os.path.isdir(full) and full not in candidates:
                    candidates.append(full)

    print("Searching for ROGII dataset...")
    for path in candidates:
        if not os.path.isdir(path):
            continue

        contents = os.listdir(path)
        has_train = "train" in contents and os.path.isdir(os.path.join(path, "train"))
        n_train = 0
        if has_train:
            n_train = len(
                glob.glob(os.path.join(path, "train", "*__horizontal_well.csv"))
            )

        if n_train > 0:
            print(f"  V Using {path} (found {n_train} train wells)")
            return path

    raise FileNotFoundError("Could not find ROGII dataset.")


DATA_DIR = find_data_dir()
# Out:
# Searching for ROGII dataset...
#   V Using /home/samer/Documents/competitions/ROGII/dataset (found 773 train wells)

# %% [markdown]
# ### Data preparation

# %%
"""Data loading, preprocessing and preparation functions using Polars and JAX.

The Conv1D model is trained with a test-like TVT_input mask. In the competition test
wells, TVT_input is known before the submission interval and missing throughout the
interval that must be predicted. If validation keeps the true TVT_input, the model can
learn an identity shortcut and report unrealistically low validation RMSE.
"""

from typing import Dict, List, Tuple, Union
import glob
import os
import pickle
import jax
import jax.numpy as jnp
import numpy as np
import polars as pl

FEATURE_COLS: List[str] = ["MD", "X", "Y", "Z", "GR", "TVT_input"]
TARGET: str = "TVT"
TVT_INPUT_COL: str = "TVT_input"
MASK_START_RATIO_RANGE: Tuple[float, float] = (0.20, 0.40)


def mask_tvt_input_for_prediction_zone(
    df: pl.DataFrame,
    rng: np.random.Generator,
    ratio_range: Tuple[float, float] = MASK_START_RATIO_RANGE,
) -> Tuple[pl.DataFrame, int]:
    """Masks a suffix of TVT_input to mimic the hidden test prediction interval.

    Args:
        df (pl.DataFrame): Input DataFrame containing the well data.
        rng (np.random.Generator): Random number generator for reproducibility.
        ratio_range (Tuple[float, float]): Range of mask start ratio relative
          to well depth.

    Returns:
        Tuple[pl.DataFrame, int]: A tuple containing the masked DataFrame and
          the index where the masking started.
    """
    if TVT_INPUT_COL not in df.columns or len(df) < 2:
        return df, len(df)

    low, high = ratio_range
    mask_start = int(round(len(df) * rng.uniform(low, high)))
    mask_start = min(max(mask_start, 1), len(df) - 1)
    row_nr = pl.int_range(0, pl.len())
    df = df.with_columns(
        pl.when(row_nr >= mask_start)
        .then(None)
        .otherwise(pl.col(TVT_INPUT_COL))
        .alias(TVT_INPUT_COL)
    )
    return df, mask_start


def preprocess(df: pl.DataFrame) -> pl.DataFrame:
    """Interpolates and fills null values in the feature columns.

    Args:
        df (pl.DataFrame): Input DataFrame with missing values.

    Returns:
        pl.DataFrame: Preprocessed DataFrame with all feature columns filled.
    """
    for col in FEATURE_COLS:
        if col in df.columns:
            df = df.with_columns(
                pl.col(col)
                .interpolate()
                .fill_null(strategy="forward")
                .fill_null(strategy="backward")
                .fill_null(0.0)
            )
    return df


def prepare_data(
    data_dir: str,
    val_ratio: float = 0.20,
    seed: int = 42,
    max_wells: Union[int, None] = None,
) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
    """Loads wells and builds train/validation arrays with test-like masking.

    Reshapes the inputs to 3D tensors compatible with Conv1D layers and uses JAX
    on CPU memory for double-precision normalization to avoid GPU OOM.

    Args:
        data_dir (str): Path to the training dataset.
        val_ratio (float): Fraction of wells to use for validation.
        seed (int): Random seed for split and masking reproducibility.
        max_wells (Union[int, None]): Maximum number of wells to load (for debugging).

    Returns:
        Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, Dict]:
          A tuple containing:
            - X_train: Preprocessed standardized training features (3D: [samples, 1, features]).
            - y_train: Standardized training target values (1D: [samples]).
            - X_val: Preprocessed standardized validation features (3D: [samples, 1, features]).
            - y_val: Standardized validation target values (1D: [samples]).
            - y_val_raw: Raw validation targets in original scale (1D: [samples]).
            - scaler: Dictionary containing standardization scaling parameters.
    """
    dataset_root = os.path.dirname(data_dir)

    # 1. Get original training IDs
    pattern_train = os.path.join(data_dir, "train", "*__horizontal_well.csv")
    files_train = sorted([os.path.basename(f) for f in glob.glob(pattern_train)])

    # 2. Get augmented training files
    # pattern_aug = os.path.join(
    #     dataset_root, "dataset_augmented", "train", "*__horizontal_well_aug.csv"
    # )
    # files_aug = sorted([os.path.basename(f) for f in glob.glob(pattern_aug)])

    # Combined training file list
    files_train_all = files_train #+ files_aug

    if max_wells:
        files_train_all = files_train_all[:max_wells]

    rng = np.random.default_rng(seed)
    n_val = max(1, int(len(files_train_all) * val_ratio))
    val_set = set(rng.permutation(len(files_train_all))[:n_val])

    train_files = [fname for i, fname in enumerate(files_train_all) if i not in val_set]
    val_files = [fname for i, fname in enumerate(files_train_all) if i in val_set]

    print(
        f"Loading {len(files_train_all)} training wells total. "
        # f"(Original: {len(files_train)}, Augmented: {len(files_aug)})."
    )

    def get_arrays(files: List[str], split_name: str) -> Tuple[np.ndarray, np.ndarray]:
        """Reads CSV files for a split, masks TVT_input, and returns merged arrays.

        Args:
            files (List[str]): List of filenames to load.
            split_name (str): Label for the dataset split (e.g. "Train", "Val").

        Returns:
            Tuple[np.ndarray, np.ndarray]: Merged features and target arrays.
        """
        feats, tgts, mask_starts = [], [], []
        for filename in files:
            try:
                # if filename in files_aug:
                #     path = os.path.join(
                #         dataset_root, "dataset_augmented", "train", filename
                #     )
                # else:
                path = os.path.join(data_dir, "train", filename)

                df = pl.read_csv(path, infer_schema_length=10000)
                df = df.filter(pl.col(TARGET).is_not_null())
                if len(df) == 0:
                    continue

                df, mask_start = mask_tvt_input_for_prediction_zone(df, rng)
                df = preprocess(df)

                feats.append(df.select(FEATURE_COLS).to_numpy().astype(np.float64))
                tgts.append(df.select(TARGET).to_numpy().ravel().astype(np.float64))
                mask_starts.append(mask_start / len(df))
            except Exception as e:
                print(f"  Skip {filename}: {e}")

        if not feats:
            raise ValueError(f"No usable wells found for {split_name} split.")

        print(
            f"{split_name} TVT_input mask start ratio: "
            f"mean={np.mean(mask_starts):.3f}, "
            f"min={np.min(mask_starts):.3f}, max={np.max(mask_starts):.3f}"
        )
        return np.concatenate(feats), np.concatenate(tgts)

    X_train_raw, y_train_raw = get_arrays(train_files, "Train")
    X_val_raw, y_val_raw = get_arrays(val_files, "Val")

    cpu_dev = jax.devices("cpu")[0]
    X_tr_jax = jax.device_put(X_train_raw, cpu_dev)
    y_tr_jax = jax.device_put(y_train_raw, cpu_dev)
    X_val_jax = jax.device_put(X_val_raw, cpu_dev)
    y_val_jax = jax.device_put(y_val_raw, cpu_dev)

    feat_mean = jnp.mean(X_tr_jax, axis=0)
    feat_std = jnp.std(X_tr_jax, axis=0)
    feat_std = jnp.where(feat_std == 0, 1.0, feat_std)

    target_mean = jnp.mean(y_tr_jax)
    target_std = jnp.std(y_tr_jax)
    target_std = jnp.where(target_std == 0, 1.0, target_std)

    X_train_n = (X_tr_jax - feat_mean) / feat_std
    y_train_n = (y_tr_jax - target_mean) / target_std
    X_val_n = (X_val_jax - feat_mean) / feat_std
    y_val_n = (y_val_jax - target_mean) / target_std

    scaler = {
        "feature_cols": FEATURE_COLS,
        "feat_mean": np.array(feat_mean),
        "feat_std": np.array(feat_std),
        "target_mean": float(target_mean),
        "target_std": float(target_std),
        "normalized": True,
        "tvt_input_masked_for_training": True,
        "mask_start_ratio_range": MASK_START_RATIO_RANGE,
    }

    # Reshape features to 3D format (samples, sequence_length=1, features) for Conv1D compatibility
    X_train_3d = np.array(X_train_n, dtype=np.float32).reshape(-1, 1, len(FEATURE_COLS))
    X_val_3d = np.array(X_val_n, dtype=np.float32).reshape(-1, 1, len(FEATURE_COLS))

    return (
        X_train_3d,
        np.array(y_train_n, dtype=np.float32),
        X_val_3d,
        np.array(y_val_n, dtype=np.float32),
        y_val_raw,
        scaler,
    )


print("Preparing dataset...")
X_train, y_train, X_val, y_val, y_val_raw, scaler = prepare_data(DATA_DIR)
print(f"Train size: {X_train.shape}, Val size: {X_val.shape}")

OUT_DIR = "../outputs"
os.makedirs(OUT_DIR, exist_ok=True)
scaler_path = os.path.join(OUT_DIR, "conv_tr_scaler_params.pkl")
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)
print(f"Scaler parameters saved to {scaler_path}")
# Out:
# Preparing dataset...
# Loading 773 training wells total.
# Train TVT_input mask start ratio: mean=0.301, min=0.200, max=0.400
# Val TVT_input mask start ratio: mean=0.295, min=0.200, max=0.399
# Train size: (4074081, 1, 6), Val size: (1018174, 1, 6)
# Scaler parameters saved to ../outputs/conv_tr_scaler_params.pkl

# %% [markdown]
# ### Model building

# %%
"""Model construction and compilation for Conv1D architecture."""

input_dim = len(FEATURE_COLS)

model = keras.Sequential()

# Expect 3D input of shape (batch, sequence_length=1, features)
model.add(layers.Input(shape=(1, input_dim)))

activation = layers.LeakyReLU(negative_slope=0.5)
initializer = "glorot_uniform"
kr_rate = 5e-05
num_layers = 2

# Layer 1
for i in range(num_layers):
    model.add(
        layers.Conv1D(
            filters=64,
            kernel_size=8,
            activation=activation,
            kernel_initializer=initializer,
            kernel_regularizer=regularizers.l2(kr_rate),
            padding="same",
        )
    )
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.2))

model.add(layers.Flatten())
model.add(layers.Dense(1, activation="linear"))

# Optimizer configuration
optimizer = keras.optimizers.AdamW(
    learning_rate=5e-06,
    # weight_decay=1e-05,
    global_clipnorm=1.0,
)

model.compile(
    optimizer=optimizer,
    loss="huber",
    metrics=[keras.metrics.RootMeanSquaredError(name="rmse")],
)

print("Conv1D model built and compiled successfully.")
model.summary()
# Out:
# Conv1D model built and compiled successfully.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 1, 64)          │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 1, 64)          │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,545 (142.75 KB)
#  Trainable params: 36,289 (141.75 KB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# ### Training

# %%
"""Train the Conv1D model with ModelCheckpoint, ReduceLROnPlateau, and EarlyStopping."""

OUT_DIR = "../outputs"
os.makedirs(OUT_DIR, exist_ok=True)
best_model_path = os.path.join(OUT_DIR, "trained_conv1d_model_augmented_v2.keras")

cbs = [
    callbacks.ModelCheckpoint(
        best_model_path, monitor="val_rmse", save_best_only=True, mode="min"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_rmse", factor=0.5, patience=30, min_lr=1e-9
    ),
    # callbacks.EarlyStopping(monitor="val_rmse", patience=15, restore_best_weights=True),
]

print("Starting training of the Conv1D model...")
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    validation_data=(X_val, y_val),
    batch_size=128,
    callbacks=cbs,
)
# Out:
# Starting training of the Conv1D model...
# Epoch 1/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.1692 - rmse: 0.6090 - val_loss: 0.0017 - val_rmse: 0.0488 - learning_rate: 5.0000e-06
# Epoch 2/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0531 - rmse: 0.3268 - val_loss: 9.0135e-04 - val_rmse: 0.0296 - learning_rate: 5.0000e-06
# Epoch 3/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0197 - rmse: 0.1960 - val_loss: 7.7061e-04 - val_rmse: 0.0253 - learning_rate: 5.0000e-06
# Epoch 4/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0118 - rmse: 0.1509 - val_loss: 7.6346e-04 - val_rmse: 0.0263 - learning_rate: 5.0000e-06
# Epoch 5/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0103 - rmse: 0.1409 - val_loss: 7.3660e-04 - val_rmse: 0.0271 - learning_rate: 5.0000e-06
# Epoch 6/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0098 - rmse: 0.1375 - val_loss: 6.2638e-04 - val_rmse: 0.0250 - learning_rate: 5.0000e-06
# Epoch 7/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0096 - rmse: 0.1365 - val_loss: 7.3050e-04 - val_rmse: 0.0306 - learning_rate: 5.0000e-06
# Epoch 8/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0095 - rmse: 0.1360 - val_loss: 5.5281e-04 - val_rmse: 0.0258 - learning_rate: 5.0000e-06
# Epoch 9/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0094 - rmse: 0.1357 - val_loss: 5.1864e-04 - val_rmse: 0.0259 - learning_rate: 5.0000e-06
# Epoch 10/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0093 - rmse: 0.1349 - val_loss: 5.4601e-04 - val_rmse: 0.0279 - learning_rate: 5.0000e-06
# Epoch 11/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0092 - rmse: 0.1346 - val_loss: 4.7243e-04 - val_rmse: 0.0260 - learning_rate: 5.0000e-06
# Epoch 12/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0092 - rmse: 0.1346 - val_loss: 4.5866e-04 - val_rmse: 0.0262 - learning_rate: 5.0000e-06
# Epoch 13/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0091 - rmse: 0.1339 - val_loss: 4.2520e-04 - val_rmse: 0.0255 - learning_rate: 5.0000e-06
# Epoch 14/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0091 - rmse: 0.1344 - val_loss: 4.4101e-04 - val_rmse: 0.0265 - learning_rate: 5.0000e-06
# Epoch 15/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0091 - rmse: 0.1340 - val_loss: 4.8104e-04 - val_rmse: 0.0283 - learning_rate: 5.0000e-06
# Epoch 16/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0090 - rmse: 0.1336 - val_loss: 3.7683e-04 - val_rmse: 0.0246 - learning_rate: 5.0000e-06
# Epoch 17/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0090 - rmse: 0.1335 - val_loss: 3.7752e-04 - val_rmse: 0.0248 - learning_rate: 5.0000e-06
# Epoch 18/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0089 - rmse: 0.1327 - val_loss: 3.8193e-04 - val_rmse: 0.0251 - learning_rate: 5.0000e-06
# Epoch 19/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0089 - rmse: 0.1328 - val_loss: 3.6866e-04 - val_rmse: 0.0246 - learning_rate: 5.0000e-06
# Epoch 20/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0088 - rmse: 0.1325 - val_loss: 3.7103e-04 - val_rmse: 0.0248 - learning_rate: 5.0000e-06
# Epoch 21/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0088 - rmse: 0.1321 - val_loss: 3.7867e-04 - val_rmse: 0.0251 - learning_rate: 5.0000e-06
# Epoch 22/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0087 - rmse: 0.1316 - val_loss: 3.6238e-04 - val_rmse: 0.0244 - learning_rate: 5.0000e-06
# Epoch 23/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0087 - rmse: 0.1313 - val_loss: 3.9434e-04 - val_rmse: 0.0257 - learning_rate: 5.0000e-06
# Epoch 24/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0085 - rmse: 0.1302 - val_loss: 4.2964e-04 - val_rmse: 0.0270 - learning_rate: 5.0000e-06
# Epoch 25/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0084 - rmse: 0.1292 - val_loss: 4.4050e-04 - val_rmse: 0.0274 - learning_rate: 5.0000e-06
# Epoch 26/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0084 - rmse: 0.1290 - val_loss: 3.9821e-04 - val_rmse: 0.0258 - learning_rate: 5.0000e-06
# Epoch 27/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0081 - rmse: 0.1272 - val_loss: 3.9476e-04 - val_rmse: 0.0257 - learning_rate: 5.0000e-06
# Epoch 28/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0081 - rmse: 0.1269 - val_loss: 4.1871e-04 - val_rmse: 0.0266 - learning_rate: 5.0000e-06
# Epoch 29/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0080 - rmse: 0.1260 - val_loss: 3.4898e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-06
# Epoch 30/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0079 - rmse: 0.1252 - val_loss: 4.0380e-04 - val_rmse: 0.0260 - learning_rate: 5.0000e-06
# Epoch 31/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0079 - rmse: 0.1249 - val_loss: 5.5900e-04 - val_rmse: 0.0315 - learning_rate: 5.0000e-06
# Epoch 32/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0078 - rmse: 0.1243 - val_loss: 4.8520e-04 - val_rmse: 0.0290 - learning_rate: 5.0000e-06
# Epoch 33/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0077 - rmse: 0.1239 - val_loss: 5.5037e-04 - val_rmse: 0.0312 - learning_rate: 5.0000e-06
# Epoch 34/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0077 - rmse: 0.1236 - val_loss: 4.7248e-04 - val_rmse: 0.0286 - learning_rate: 5.0000e-06
# Epoch 35/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0077 - rmse: 0.1233 - val_loss: 5.0769e-04 - val_rmse: 0.0299 - learning_rate: 5.0000e-06
# Epoch 36/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0077 - rmse: 0.1233 - val_loss: 3.5177e-04 - val_rmse: 0.0241 - learning_rate: 5.0000e-06
# Epoch 37/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0077 - rmse: 0.1234 - val_loss: 4.2844e-04 - val_rmse: 0.0272 - learning_rate: 5.0000e-06
# Epoch 38/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0076 - rmse: 0.1228 - val_loss: 3.5715e-04 - val_rmse: 0.0245 - learning_rate: 5.0000e-06
# Epoch 39/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0076 - rmse: 0.1230 - val_loss: 3.6430e-04 - val_rmse: 0.0248 - learning_rate: 5.0000e-06
# Epoch 40/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0076 - rmse: 0.1229 - val_loss: 4.7580e-04 - val_rmse: 0.0290 - learning_rate: 5.0000e-06
# Epoch 41/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0076 - rmse: 0.1226 - val_loss: 3.8646e-04 - val_rmse: 0.0258 - learning_rate: 5.0000e-06
# Epoch 42/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0075 - rmse: 0.1219 - val_loss: 4.5636e-04 - val_rmse: 0.0284 - learning_rate: 5.0000e-06
# Epoch 43/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0075 - rmse: 0.1222 - val_loss: 3.9661e-04 - val_rmse: 0.0262 - learning_rate: 5.0000e-06
# Epoch 44/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0075 - rmse: 0.1222 - val_loss: 3.7087e-04 - val_rmse: 0.0253 - learning_rate: 5.0000e-06
# Epoch 45/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0074 - rmse: 0.1215 - val_loss: 4.0007e-04 - val_rmse: 0.0265 - learning_rate: 5.0000e-06
# Epoch 46/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0075 - rmse: 0.1217 - val_loss: 3.4407e-04 - val_rmse: 0.0243 - learning_rate: 5.0000e-06
# Epoch 47/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0075 - rmse: 0.1217 - val_loss: 3.7041e-04 - val_rmse: 0.0254 - learning_rate: 5.0000e-06
# Epoch 48/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0075 - rmse: 0.1221 - val_loss: 3.4104e-04 - val_rmse: 0.0242 - learning_rate: 5.0000e-06
# Epoch 49/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0074 - rmse: 0.1214 - val_loss: 5.0911e-04 - val_rmse: 0.0304 - learning_rate: 5.0000e-06
# Epoch 50/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0075 - rmse: 0.1220 - val_loss: 3.6195e-04 - val_rmse: 0.0251 - learning_rate: 5.0000e-06
# Epoch 51/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0074 - rmse: 0.1213 - val_loss: 3.5406e-04 - val_rmse: 0.0249 - learning_rate: 5.0000e-06
# Epoch 52/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0073 - rmse: 0.1208 - val_loss: 4.2839e-04 - val_rmse: 0.0277 - learning_rate: 5.0000e-06
# Epoch 53/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0074 - rmse: 0.1214 - val_loss: 3.2574e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-06
# Epoch 54/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0074 - rmse: 0.1215 - val_loss: 3.4275e-04 - val_rmse: 0.0245 - learning_rate: 5.0000e-06
# Epoch 55/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0074 - rmse: 0.1210 - val_loss: 3.8899e-04 - val_rmse: 0.0264 - learning_rate: 5.0000e-06
# Epoch 56/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 40s 1ms/step - loss: 0.0074 - rmse: 0.1209 - val_loss: 3.8266e-04 - val_rmse: 0.0261 - learning_rate: 5.0000e-06
# Epoch 57/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0074 - rmse: 0.1212 - val_loss: 3.5623e-04 - val_rmse: 0.0251 - learning_rate: 5.0000e-06
# Epoch 58/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0073 - rmse: 0.1208 - val_loss: 3.4977e-04 - val_rmse: 0.0249 - learning_rate: 5.0000e-06
# Epoch 59/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0073 - rmse: 0.1209 - val_loss: 3.2236e-04 - val_rmse: 0.0238 - learning_rate: 5.0000e-06
# Epoch 60/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.2072e-04 - val_rmse: 0.0238 - learning_rate: 2.5000e-06
# Epoch 61/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.8326e-04 - val_rmse: 0.0263 - learning_rate: 2.5000e-06
# Epoch 62/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0073 - rmse: 0.1205 - val_loss: 3.4354e-04 - val_rmse: 0.0247 - learning_rate: 2.5000e-06
# Epoch 63/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1209 - val_loss: 3.2740e-04 - val_rmse: 0.0241 - learning_rate: 2.5000e-06
# Epoch 64/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.4834e-04 - val_rmse: 0.0250 - learning_rate: 2.5000e-06
# Epoch 65/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0074 - rmse: 0.1211 - val_loss: 3.7306e-04 - val_rmse: 0.0259 - learning_rate: 2.5000e-06
# Epoch 66/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1208 - val_loss: 3.3317e-04 - val_rmse: 0.0244 - learning_rate: 2.5000e-06
# Epoch 67/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0074 - rmse: 0.1209 - val_loss: 3.3292e-04 - val_rmse: 0.0244 - learning_rate: 2.5000e-06
# Epoch 68/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 3.6943e-04 - val_rmse: 0.0258 - learning_rate: 2.5000e-06
# Epoch 69/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0074 - rmse: 0.1211 - val_loss: 3.1548e-04 - val_rmse: 0.0237 - learning_rate: 2.5000e-06
# Epoch 70/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1205 - val_loss: 3.3480e-04 - val_rmse: 0.0245 - learning_rate: 2.5000e-06
# Epoch 71/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1205 - val_loss: 3.4135e-04 - val_rmse: 0.0248 - learning_rate: 2.5000e-06
# Epoch 72/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 4.2148e-04 - val_rmse: 0.0278 - learning_rate: 2.5000e-06
# Epoch 73/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1209 - val_loss: 3.3163e-04 - val_rmse: 0.0244 - learning_rate: 2.5000e-06
# Epoch 74/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 3.3199e-04 - val_rmse: 0.0244 - learning_rate: 2.5000e-06
# Epoch 75/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1206 - val_loss: 4.3451e-04 - val_rmse: 0.0283 - learning_rate: 2.5000e-06
# Epoch 76/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1209 - val_loss: 3.2649e-04 - val_rmse: 0.0242 - learning_rate: 2.5000e-06
# Epoch 77/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1206 - val_loss: 3.2777e-04 - val_rmse: 0.0243 - learning_rate: 2.5000e-06
# Epoch 78/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0073 - rmse: 0.1202 - val_loss: 3.1874e-04 - val_rmse: 0.0239 - learning_rate: 2.5000e-06
# Epoch 79/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.4015e-04 - val_rmse: 0.0248 - learning_rate: 2.5000e-06
# Epoch 80/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 3.2946e-04 - val_rmse: 0.0244 - learning_rate: 2.5000e-06
# Epoch 81/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.5720e-04 - val_rmse: 0.0255 - learning_rate: 2.5000e-06
# Epoch 82/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.7257e-04 - val_rmse: 0.0261 - learning_rate: 2.5000e-06
# Epoch 83/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1205 - val_loss: 3.6749e-04 - val_rmse: 0.0259 - learning_rate: 2.5000e-06
# Epoch 84/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1206 - val_loss: 3.2275e-04 - val_rmse: 0.0242 - learning_rate: 2.5000e-06
# Epoch 85/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.5298e-04 - val_rmse: 0.0254 - learning_rate: 2.5000e-06
# Epoch 86/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1208 - val_loss: 3.5906e-04 - val_rmse: 0.0257 - learning_rate: 2.5000e-06
# Epoch 87/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.8679e-04 - val_rmse: 0.0267 - learning_rate: 2.5000e-06
# Epoch 88/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.2620e-04 - val_rmse: 0.0244 - learning_rate: 2.5000e-06
# Epoch 89/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.5235e-04 - val_rmse: 0.0254 - learning_rate: 2.5000e-06
# Epoch 90/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.3754e-04 - val_rmse: 0.0248 - learning_rate: 2.5000e-06
# Epoch 91/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.7327e-04 - val_rmse: 0.0263 - learning_rate: 2.5000e-06
# Epoch 92/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.1351e-04 - val_rmse: 0.0239 - learning_rate: 2.5000e-06
# Epoch 93/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.7825e-04 - val_rmse: 0.0265 - learning_rate: 2.5000e-06
# Epoch 94/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0073 - rmse: 0.1202 - val_loss: 3.3214e-04 - val_rmse: 0.0247 - learning_rate: 2.5000e-06
# Epoch 95/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.1341e-04 - val_rmse: 0.0239 - learning_rate: 2.5000e-06
# Epoch 96/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1206 - val_loss: 3.3988e-04 - val_rmse: 0.0250 - learning_rate: 2.5000e-06
# Epoch 97/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 4.8419e-04 - val_rmse: 0.0302 - learning_rate: 2.5000e-06
# Epoch 98/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.6809e-04 - val_rmse: 0.0261 - learning_rate: 2.5000e-06
# Epoch 99/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1207 - val_loss: 3.2285e-04 - val_rmse: 0.0243 - learning_rate: 2.5000e-06
# Epoch 100/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.2245e-04 - val_rmse: 0.0243 - learning_rate: 1.2500e-06
# Epoch 101/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.2775e-04 - val_rmse: 0.0246 - learning_rate: 1.2500e-06
# Epoch 102/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0073 - rmse: 0.1202 - val_loss: 3.4193e-04 - val_rmse: 0.0251 - learning_rate: 1.2500e-06
# Epoch 103/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.2372e-04 - val_rmse: 0.0244 - learning_rate: 1.2500e-06
# Epoch 104/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.2116e-04 - val_rmse: 0.0243 - learning_rate: 1.2500e-06
# Epoch 105/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.2648e-04 - val_rmse: 0.0245 - learning_rate: 1.2500e-06
# Epoch 106/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.2921e-04 - val_rmse: 0.0246 - learning_rate: 1.2500e-06
# Epoch 107/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1202 - val_loss: 3.8454e-04 - val_rmse: 0.0268 - learning_rate: 1.2500e-06
# Epoch 108/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.8297e-04 - val_rmse: 0.0267 - learning_rate: 1.2500e-06
# Epoch 109/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 3.1645e-04 - val_rmse: 0.0241 - learning_rate: 1.2500e-06
# Epoch 110/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.4398e-04 - val_rmse: 0.0253 - learning_rate: 1.2500e-06
# Epoch 111/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.7697e-04 - val_rmse: 0.0265 - learning_rate: 1.2500e-06
# Epoch 112/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1202 - val_loss: 3.3947e-04 - val_rmse: 0.0251 - learning_rate: 1.2500e-06
# Epoch 113/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.1293e-04 - val_rmse: 0.0240 - learning_rate: 1.2500e-06
# Epoch 114/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.3822e-04 - val_rmse: 0.0250 - learning_rate: 1.2500e-06
# Epoch 115/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0072 - rmse: 0.1202 - val_loss: 3.0470e-04 - val_rmse: 0.0237 - learning_rate: 1.2500e-06
# Epoch 116/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.3584e-04 - val_rmse: 0.0250 - learning_rate: 1.2500e-06
# Epoch 117/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1194 - val_loss: 3.2071e-04 - val_rmse: 0.0243 - learning_rate: 1.2500e-06
# Epoch 118/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.5500e-04 - val_rmse: 0.0257 - learning_rate: 1.2500e-06
# Epoch 119/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.6870e-04 - val_rmse: 0.0262 - learning_rate: 1.2500e-06
# Epoch 120/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.3138e-04 - val_rmse: 0.0248 - learning_rate: 1.2500e-06
# Epoch 121/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.2694e-04 - val_rmse: 0.0246 - learning_rate: 1.2500e-06
# Epoch 122/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.7480e-04 - val_rmse: 0.0265 - learning_rate: 1.2500e-06
# Epoch 123/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.1714e-04 - val_rmse: 0.0242 - learning_rate: 1.2500e-06
# Epoch 124/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 4.1955e-04 - val_rmse: 0.0281 - learning_rate: 1.2500e-06
# Epoch 125/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.1744e-04 - val_rmse: 0.0242 - learning_rate: 1.2500e-06
# Epoch 126/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.1159e-04 - val_rmse: 0.0240 - learning_rate: 1.2500e-06
# Epoch 127/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0073 - rmse: 0.1205 - val_loss: 3.1827e-04 - val_rmse: 0.0243 - learning_rate: 1.2500e-06
# Epoch 128/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.4495e-04 - val_rmse: 0.0254 - learning_rate: 1.2500e-06
# Epoch 129/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.2714e-04 - val_rmse: 0.0247 - learning_rate: 1.2500e-06
# Epoch 130/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.2704e-04 - val_rmse: 0.0247 - learning_rate: 6.2500e-07
# Epoch 131/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.1420e-04 - val_rmse: 0.0241 - learning_rate: 6.2500e-07
# Epoch 132/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 4.1323e-04 - val_rmse: 0.0279 - learning_rate: 6.2500e-07
# Epoch 133/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.1997e-04 - val_rmse: 0.0244 - learning_rate: 6.2500e-07
# Epoch 134/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.3139e-04 - val_rmse: 0.0248 - learning_rate: 6.2500e-07
# Epoch 135/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.2688e-04 - val_rmse: 0.0247 - learning_rate: 6.2500e-07
# Epoch 136/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1202 - val_loss: 3.3133e-04 - val_rmse: 0.0248 - learning_rate: 6.2500e-07
# Epoch 137/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.1532e-04 - val_rmse: 0.0242 - learning_rate: 6.2500e-07
# Epoch 138/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.3823e-04 - val_rmse: 0.0251 - learning_rate: 6.2500e-07
# Epoch 139/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.1360e-04 - val_rmse: 0.0241 - learning_rate: 6.2500e-07
# Epoch 140/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.3701e-04 - val_rmse: 0.0251 - learning_rate: 6.2500e-07
# Epoch 141/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0071 - rmse: 0.1194 - val_loss: 3.1905e-04 - val_rmse: 0.0244 - learning_rate: 6.2500e-07
# Epoch 142/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.1446e-04 - val_rmse: 0.0242 - learning_rate: 6.2500e-07
# Epoch 143/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.9258e-04 - val_rmse: 0.0272 - learning_rate: 6.2500e-07
# Epoch 144/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.2087e-04 - val_rmse: 0.0244 - learning_rate: 6.2500e-07
# Epoch 145/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.5650e-04 - val_rmse: 0.0259 - learning_rate: 6.2500e-07
# Epoch 146/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 3.2327e-04 - val_rmse: 0.0245 - learning_rate: 6.2500e-07
# Epoch 147/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 60s 2ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.0359e-04 - val_rmse: 0.0237 - learning_rate: 6.2500e-07
# Epoch 148/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.1540e-04 - val_rmse: 0.0242 - learning_rate: 6.2500e-07
# Epoch 149/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1195 - val_loss: 3.1624e-04 - val_rmse: 0.0243 - learning_rate: 6.2500e-07
# Epoch 150/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.2235e-04 - val_rmse: 0.0245 - learning_rate: 6.2500e-07
# Epoch 151/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.1607e-04 - val_rmse: 0.0242 - learning_rate: 6.2500e-07
# Epoch 152/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0071 - rmse: 0.1192 - val_loss: 3.0431e-04 - val_rmse: 0.0238 - learning_rate: 6.2500e-07
# Epoch 153/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.1925e-04 - val_rmse: 0.0244 - learning_rate: 6.2500e-07
# Epoch 154/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1194 - val_loss: 3.2079e-04 - val_rmse: 0.0244 - learning_rate: 6.2500e-07
# Epoch 155/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.1099e-04 - val_rmse: 0.0240 - learning_rate: 6.2500e-07
# Epoch 156/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.8165e-04 - val_rmse: 0.0268 - learning_rate: 6.2500e-07
# Epoch 157/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.1014e-04 - val_rmse: 0.0240 - learning_rate: 6.2500e-07
# Epoch 158/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.0758e-04 - val_rmse: 0.0239 - learning_rate: 6.2500e-07
# Epoch 159/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.1633e-04 - val_rmse: 0.0243 - learning_rate: 6.2500e-07
# Epoch 160/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.1912e-04 - val_rmse: 0.0244 - learning_rate: 3.1250e-07
# Epoch 161/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.0726e-04 - val_rmse: 0.0239 - learning_rate: 3.1250e-07
# Epoch 162/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.2375e-04 - val_rmse: 0.0246 - learning_rate: 3.1250e-07
# Epoch 163/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 45s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.2568e-04 - val_rmse: 0.0247 - learning_rate: 3.1250e-07
# Epoch 164/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.0762e-04 - val_rmse: 0.0239 - learning_rate: 3.1250e-07
# Epoch 165/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0073 - rmse: 0.1203 - val_loss: 3.0533e-04 - val_rmse: 0.0238 - learning_rate: 3.1250e-07
# Epoch 166/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 43s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.2733e-04 - val_rmse: 0.0247 - learning_rate: 3.1250e-07
# Epoch 167/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.1514e-04 - val_rmse: 0.0242 - learning_rate: 3.1250e-07
# Epoch 168/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.5764e-04 - val_rmse: 0.0259 - learning_rate: 3.1250e-07
# Epoch 169/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.7866e-04 - val_rmse: 0.0267 - learning_rate: 3.1250e-07
# Epoch 170/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.4429e-04 - val_rmse: 0.0254 - learning_rate: 3.1250e-07
# Epoch 171/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.1311e-04 - val_rmse: 0.0242 - learning_rate: 3.1250e-07
# Epoch 172/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.1420e-04 - val_rmse: 0.0242 - learning_rate: 3.1250e-07
# Epoch 173/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.2396e-04 - val_rmse: 0.0246 - learning_rate: 3.1250e-07
# Epoch 174/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0073 - rmse: 0.1204 - val_loss: 3.2323e-04 - val_rmse: 0.0246 - learning_rate: 3.1250e-07
# Epoch 175/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.1384e-04 - val_rmse: 0.0242 - learning_rate: 3.1250e-07
# Epoch 176/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.1643e-04 - val_rmse: 0.0243 - learning_rate: 3.1250e-07
# Epoch 177/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.3460e-04 - val_rmse: 0.0250 - learning_rate: 3.1250e-07
# Epoch 178/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0071 - rmse: 0.1194 - val_loss: 3.2471e-04 - val_rmse: 0.0246 - learning_rate: 3.1250e-07
# Epoch 179/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.1736e-04 - val_rmse: 0.0243 - learning_rate: 3.1250e-07
# Epoch 180/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.6257e-04 - val_rmse: 0.0261 - learning_rate: 3.1250e-07
# Epoch 181/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 47s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.1716e-04 - val_rmse: 0.0243 - learning_rate: 3.1250e-07
# Epoch 182/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 46s 1ms/step - loss: 0.0071 - rmse: 0.1192 - val_loss: 3.0788e-04 - val_rmse: 0.0239 - learning_rate: 3.1250e-07
# Epoch 183/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0071 - rmse: 0.1193 - val_loss: 3.1556e-04 - val_rmse: 0.0243 - learning_rate: 3.1250e-07
# Epoch 184/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.1929e-04 - val_rmse: 0.0244 - learning_rate: 3.1250e-07
# Epoch 185/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.5421e-04 - val_rmse: 0.0258 - learning_rate: 3.1250e-07
# Epoch 186/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.0776e-04 - val_rmse: 0.0239 - learning_rate: 3.1250e-07
# Epoch 187/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1196 - val_loss: 3.0736e-04 - val_rmse: 0.0239 - learning_rate: 3.1250e-07
# Epoch 188/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1202 - val_loss: 3.2533e-04 - val_rmse: 0.0247 - learning_rate: 3.1250e-07
# Epoch 189/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 44s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.1128e-04 - val_rmse: 0.0241 - learning_rate: 3.1250e-07
# Epoch 190/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0071 - rmse: 0.1194 - val_loss: 3.7453e-04 - val_rmse: 0.0266 - learning_rate: 1.5625e-07
# Epoch 191/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1202 - val_loss: 3.2786e-04 - val_rmse: 0.0248 - learning_rate: 1.5625e-07
# Epoch 192/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 41s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.0706e-04 - val_rmse: 0.0239 - learning_rate: 1.5625e-07
# Epoch 193/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1201 - val_loss: 3.4079e-04 - val_rmse: 0.0253 - learning_rate: 1.5625e-07
# Epoch 194/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.3451e-04 - val_rmse: 0.0250 - learning_rate: 1.5625e-07
# Epoch 195/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1199 - val_loss: 3.1467e-04 - val_rmse: 0.0242 - learning_rate: 1.5625e-07
# Epoch 196/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1198 - val_loss: 3.2503e-04 - val_rmse: 0.0247 - learning_rate: 1.5625e-07
# Epoch 197/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1200 - val_loss: 3.3952e-04 - val_rmse: 0.0252 - learning_rate: 1.5625e-07
# Epoch 198/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.2035e-04 - val_rmse: 0.0245 - learning_rate: 1.5625e-07
# Epoch 199/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1195 - val_loss: 3.1945e-04 - val_rmse: 0.0244 - learning_rate: 1.5625e-07
# Epoch 200/200
# 31829/31829 ━━━━━━━━━━━━━━━━━━━━ 42s 1ms/step - loss: 0.0072 - rmse: 0.1197 - val_loss: 3.8073e-04 - val_rmse: 0.0268 - learning_rate: 1.5625e-07

# %% [markdown]
# ### Evaluation

# %%
"""Load the best model and evaluate its final RMSE on raw scale using JAX."""

# Denormalize using JAX on CPU device
cpu_dev = jax.devices("cpu")[0]
target_mean = jax.device_put(scaler["target_mean"], cpu_dev)
target_std = jax.device_put(scaler["target_std"], cpu_dev)
y_val_raw_jnp = jax.device_put(y_val_raw, cpu_dev)

# Predict on val set (normalized scale)
yp_n = model.predict(X_val, batch_size=128).ravel()
yp_n_jnp = jax.device_put(yp_n, cpu_dev)

# Denormalize predictions
yp_jnp = (yp_n_jnp * target_std) + target_mean

# Calculate error and RMSE using JAX
err = yp_jnp - y_val_raw_jnp
rmse = float(jnp.sqrt(jnp.mean(jnp.square(err))))
print(f"\nFinal Val RMSE (Optimized Conv1D Model, RAW SCALE): {rmse:.4f}")
# Out:
# 7955/7955 ━━━━━━━━━━━━━━━━━━━━ 5s 581us/step
#
# Final Val RMSE (Optimized Conv1D Model, RAW SCALE): 16.8303

# %%
"""Plots training and validation curves and saves them to the analytics directory."""

import matplotlib.pyplot as plt

ANALYTICS_DIR = "../analytics"
os.makedirs(ANALYTICS_DIR, exist_ok=True)


def plot_history(history):
    """Plots model loss and root mean squared error curves.

    Args:
        history: Keras History object.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Loss curve
    ax1.plot(history.history["loss"], label="Train")
    ax1.plot(history.history["val_loss"], label="Val")
    ax1.set_title("Conv1D Model Loss (MSE)")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.legend()
    ax1.grid(True)

    # RMSE curve
    ax2.plot(history.history["rmse"], label="Train")
    ax2.plot(history.history["val_rmse"], label="Val")
    ax2.set_title("Conv1D Model RMSE")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("RMSE")
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.savefig(os.path.join(ANALYTICS_DIR, "conv1d_training_history.png"))
    plt.show()


if "history" in locals():
    plot_history(history)

# %%
def plot_pred_vs_actual(y_true, y_pred, val_rmse):
    """Plots predicted vs actual values on raw scale and saves it to analytics."""
    plt.figure(figsize=(10, 6))
    plt.scatter(np.array(y_true), np.array(y_pred), alpha=0.1, s=1, color="blue")

    # Draw perfect prediction line
    min_val = min(float(y_true.min()), float(y_pred.min()))
    max_val = max(float(y_true.max()), float(y_pred.max()))
    plt.plot(
        [min_val, max_val], [min_val, max_val], "r--", lw=2, label="Perfect Prediction"
    )

    plt.title(f"Actual vs Predicted TVT (Val Set - Conv1D)\nRMSE: {val_rmse:.4f}")
    plt.xlabel("Actual TVT")
    plt.ylabel("Predicted TVT")
    plt.legend()
    plt.grid(True)

    plt.savefig(os.path.join(ANALYTICS_DIR, "conv1d_val_pred_vs_actual.png"))
    plt.show()


if "y_val_raw" in locals() and "yp_jnp" in locals():
    plot_pred_vs_actual(y_val_raw, yp_jnp, rmse)
